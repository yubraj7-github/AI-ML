# %% [markdown]
# ***Generators in Python:***<br>
# ->A generator is a special type of function that gives one value at a time instead of giving all values at once.<br>
# Think like this:<br>
# A normal function returns everything → heavy<br>
# A generator returns values one by one → light and fast<br>
#
# It uses the yield keyword instead of return.<br>
#
# Why use Generators?<br>
# i.Saves memory<br>
# ii.Fast for big data<br>
# iii.You can loop through the values easily<br>
#
# ***Lazy data loading*:**<br>
# ->Lazy data loading means:<br>
# i.Don’t load all data at once<br>
# ii.Load only when needed (one by one or small chunks)<br>
#
# This saves memory and makes your program faster, especially with big files or big datasets.<br>
#
# Example in real life:<br>
# Imagine you have a 1000-page book.<br>
# Normal loading = bring whole book at once → heavy<br>
# Lazy loading = bring only 1 page when you need → light<br>

# %%
#Create a fetch_page(url) generator that sends a GET request and yields the raw HTML of each page until no next page exists.

import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

def fetch_page(url):
    """Generator that fetches each page and moves to next page."""
    
    while url:   # continue until url becomes None
      
        #  Get the HTML
        response = requests.get(url)
        html = response.text
        
        # Yield (give) the HTML of current page
        yield html
        
        # Parse HTML to find next page URL
        soup = BeautifulSoup(html, "html.parser")
        
        next_link = soup.find("li", class_="next")  # find next page button
        
        if next_link and next_link.a:
            # Build next page URL
            next_href = next_link.a.get("href")
              # Turn relative href into absolute URL
            url = urljoin(start_url, next_href)
        else:
            # No next page stop loop
            url = None
start_url ="https://quotes.toscrape.com/page/1/"

for page in fetch_page(start_url):
    print("Got a page!")
    print(page[:50])
    print("-"*50)
# Out:
# Got a page!
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta cha
# --------------------------------------------------
# Got a page!
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta cha
# --------------------------------------------------
# Got a page!
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta cha
# --------------------------------------------------
# Got a page!
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta cha
# --------------------------------------------------
# Got a page!
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta cha
# --------------------------------------------------
# Got a page!
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta cha
# --------------------------------------------------
# Got a page!
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta cha
# --------------------------------------------------
# Got a page!
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta cha
# --------------------------------------------------
# Got a page!
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta cha
# --------------------------------------------------
# Got a page!
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta cha
# --------------------------------------------------

# %%
#Create a parse_items(html) generator that extracts all items from a single page and yields each item one-by-one instead of returning a list.
import requests
from bs4 import BeautifulSoup

def parse_items(html):
    """Generator that extracts each book item from a single page."""
    soup = BeautifulSoup(html, "html.parser")
    
    # Find all book containers
    books = soup.find_all("article", class_="product_pod")
    
    for book in books:
        # Extract book title
        title = book.h3.a["title"]
        # Extract book price
        price = book.find("p", class_="price_color").text
        # Extract availability
        availability = book.find("p", class_="instock availability").text.strip()
        
        # Yield a dictionary with book info
        yield {
            "title": title,
            "price": price,
            "availability": availability
        }

# Example usage
url = "http://books.toscrape.com/catalogue/page-1.html"
html = requests.get(url).text

for book in parse_items(html):
    print(book)
# Out:
# {'title': 'A Light in the Attic', 'price': 'Â£51.77', 'availability': 'In stock'}
# {'title': 'Tipping the Velvet', 'price': 'Â£53.74', 'availability': 'In stock'}
# {'title': 'Soumission', 'price': 'Â£50.10', 'availability': 'In stock'}
# {'title': 'Sharp Objects', 'price': 'Â£47.82', 'availability': 'In stock'}
# {'title': 'Sapiens: A Brief History of Humankind', 'price': 'Â£54.23', 'availability': 'In stock'}
# {'title': 'The Requiem Red', 'price': 'Â£22.65', 'availability': 'In stock'}
# {'title': 'The Dirty Little Secrets of Getting Your Dream Job', 'price': 'Â£33.34', 'availability': 'In stock'}
# {'title': 'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull', 'price': 'Â£17.93', 'availability': 'In stock'}
# {'title': 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics', 'price': 'Â£22.60', 'availability': 'In stock'}
# {'title': 'The Black Maria', 'price': 'Â£52.15', 'availability': 'In stock'}
# {'title': 'Starving Hearts (Triangular Trade Trilogy, #1)', 'price': 'Â£13.99', 'availability': 'In stock'}
# {'title': "Shakespeare's Sonnets", 'price': 'Â£20.66', 'availability': 'In stock'}
# {'title': 'Set Me Free', 'price': 'Â£17.46', 'availability': 'In stock'}
# {'title': "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)", 'price': 'Â£52.29', 'availability': 'In stock'}
# {'title': 'Rip it Up and Start Again', 'price': 'Â£35.02', 'availability': 'In stock'}
# {'title': 'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991', 'price': 'Â£57.25', 'availability': 'In stock'}
# {'title': 'Olio', 'price': 'Â£23.88', 'availability': 'In stock'}
# {'title': 'Mesaerion: The Best Science Fiction Stories 1800-1849', 'price': 'Â£37.59', 'availability': 'In stock'}
# {'title': 'Libertarianism for Beginners', 'price': 'Â£51.33', 'availability': 'In stock'}
# {'title': "It's Only the Himalayas", 'price': 'Â£45.17', 'availability': 'In stock'}

# %%
#Build a scrape_all() generator that connects fetch_page() and parse_items() to yield scraped items lazily across all pages.
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# Generator to fetch pages lazily
def fetch_page(url):

    while url:
        response = requests.get(url)
        html = response.text
        yield html

        # Find next page
        soup = BeautifulSoup(html, "html.parser")
        next_button = soup.find("li", class_="next")
        if next_button and next_button.a:
            next_href = next_button.a.get("href")
            url = urljoin(start_url, next_href)
        else:
            url = None

# Generator to parse items from a single page
def parse_items(html):
    soup = BeautifulSoup(html, "html.parser")
    books = soup.find_all("article", class_="product_pod")
    for book in books:
        title = book.h3.a["title"]
        price = book.find("p", class_="price_color").text
        availability = book.find("p", class_="instock availability").text.strip()
        yield {
            "title": title,
            "price": price,
            "availability": availability
        }

# Generator to scrape all items across all pages lazily
def scrape_all(start_url):
    for page_html in fetch_page(start_url):          # fetch one page at a time
        for item in parse_items(page_html):         # parse items lazily from that page
            yield item                              # yield one item at a time

# Usage example
start_url = "http://books.toscrape.com/catalogue/page-1.html"
for book in scrape_all(start_url):
    print(book)
# Out:
# {'title': 'A Light in the Attic', 'price': 'Â£51.77', 'availability': 'In stock'}
# {'title': 'Tipping the Velvet', 'price': 'Â£53.74', 'availability': 'In stock'}
# {'title': 'Soumission', 'price': 'Â£50.10', 'availability': 'In stock'}
# {'title': 'Sharp Objects', 'price': 'Â£47.82', 'availability': 'In stock'}
# {'title': 'Sapiens: A Brief History of Humankind', 'price': 'Â£54.23', 'availability': 'In stock'}
# {'title': 'The Requiem Red', 'price': 'Â£22.65', 'availability': 'In stock'}
# {'title': 'The Dirty Little Secrets of Getting Your Dream Job', 'price': 'Â£33.34', 'availability': 'In stock'}
# {'title': 'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull', 'price': 'Â£17.93', 'availability': 'In stock'}
# {'title': 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics', 'price': 'Â£22.60', 'availability': 'In stock'}
# {'title': 'The Black Maria', 'price': 'Â£52.15', 'availability': 'In stock'}
# {'title': 'Starving Hearts (Triangular Trade Trilogy, #1)', 'price': 'Â£13.99', 'availability': 'In stock'}
# {'title': "Shakespeare's Sonnets", 'price': 'Â£20.66', 'availability': 'In stock'}
# {'title': 'Set Me Free', 'price': 'Â£17.46', 'availability': 'In stock'}
# {'title': "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)", 'price': 'Â£52.29', 'availability': 'In stock'}
# {'title': 'Rip it Up and Start Again', 'price': 'Â£35.02', 'availability': 'In stock'}
# {'title': 'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991', 'price': 'Â£57.25', 'availability': 'In stock'}
# {'title': 'Olio', 'price': 'Â£23.88', 'availability': 'In stock'}
# {'title': 'Mesaerion: The Best Science Fiction Stories 1800-1849', 'price': 'Â£37.59', 'availability': 'In stock'}
# {'title': 'Libertarianism for Beginners', 'price': 'Â£51.33', 'availability': 'In stock'}
# {'title': "It's Only the Himalayas", 'price': 'Â£45.17', 'availability': 'In stock'}
# {'title': 'In Her Wake', 'price': 'Â£12.84', 'availability': 'In stock'}
# {'title': 'How Music Works', 'price': 'Â£37.32', 'availability': 'In stock'}
# {'title': 'Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More', 'price': 'Â£30.52', 'availability': 'In stock'}
# {'title': 'Chase Me (Paris Nights #2)', 'price': 'Â£25.27', 'availability': 'In stock'}
# {'title': 'Black Dust', 'price': 'Â£34.53', 'availability': 'In stock'}
# {'title': 'Birdsong: A Story in Pictures', 'price': 'Â£54.64', 'availability': 'In stock'}
# {'title': "America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana", 'price': 'Â£22.50', 'availability': 'In stock'}
# {'title': 'Aladdin and His Wonderful Lamp', 'price': 'Â£53.13', 'availability': 'In stock'}
# {'title': 'Worlds Elsewhere: Journeys Around Shakespeareâ\x80\x99s Globe', 'price': 'Â£40.30', 'availability': 'In stock'}
# {'title': 'Wall and Piece', 'price': 'Â£44.18', 'availability': 'In stock'}
# {'title': 'The Four Agreements: A Practical Guide to Personal Freedom', 'price': 'Â£17.66', 'availability': 'In stock'}
# {'title': 'The Five Love Languages: How to Express Heartfelt Commitment to Your Mate', 'price': 'Â£31.05', 'availability': 'In stock'}
# {'title': 'The Elephant Tree', 'price': 'Â£23.82', 'availability': 'In stock'}
# {'title': 'The Bear and the Piano', 'price': 'Â£36.89', 'availability': 'In stock'}
# {'title': "Sophie's World", 'price': 'Â£15.94', 'availability': 'In stock'}
# {'title': 'Penny Maybe', 'price': 'Â£33.29', 'availability': 'In stock'}
# {'title': 'Maude (1883-1993):She Grew Up with the country', 'price': 'Â£18.02', 'availability': 'In stock'}
# {'title': 'In a Dark, Dark Wood', 'price': 'Â£19.63', 'availability': 'In stock'}
# {'title': 'Behind Closed Doors', 'price': 'Â£52.22', 'availability': 'In stock'}
# {'title': "You can't bury them all: Poems", 'price': 'Â£33.63', 'availability': 'In stock'}
# {'title': 'Slow States of Collapse: Poems', 'price': 'Â£57.31', 'availability': 'In stock'}
# {'title': 'Reasons to Stay Alive', 'price': 'Â£26.41', 'availability': 'In stock'}
# {'title': 'Private Paris (Private #10)', 'price': 'Â£47.61', 'availability': 'In stock'}
# {'title': '#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.', 'price': 'Â£23.11', 'availability': 'In stock'}
# {'title': 'Without Borders (Wanderlove #1)', 'price': 'Â£45.07', 'availability': 'In stock'}
# {'title': 'When We Collided', 'price': 'Â£31.77', 'availability': 'In stock'}
# {'title': 'We Love You, Charlie Freeman', 'price': 'Â£50.27', 'availability': 'In stock'}
# {'title': 'Untitled Collection: Sabbath Poems 2014', 'price': 'Â£14.27', 'availability': 'In stock'}
# {'title': 'Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails & Other Wonders of the Urban Wilderness', 'price': 'Â£44.18', 'availability': 'In stock'}
# {'title': 'Unicorn Tracks', 'price': 'Â£18.78', 'availability': 'In stock'}
# {'title': 'Unbound: How Eight Technologies Made Us Human, Transformed Society, and Brought Our World to the Brink', 'price': 'Â£25.52', 'availability': 'In stock'}
# {'title': 'Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2)', 'price': 'Â£16.28', 'availability': 'In stock'}
# {'title': 'Throwing Rocks at the Google Bus: How Growth Became the Enemy of Prosperity', 'price': 'Â£31.12', 'availability': 'In stock'}
# {'title': 'This One Summer', 'price': 'Â£19.49', 'availability': 'In stock'}
# {'title': 'Thirst', 'price': 'Â£17.27', 'availability': 'In stock'}
# {'title': 'The Torch Is Passed: A Harding Family Story', 'price': 'Â£19.09', 'availability': 'In stock'}
# {'title': 'The Secret of Dreadwillow Carse', 'price': 'Â£56.13', 'availability': 'In stock'}
# {'title': 'The Pioneer Woman Cooks: Dinnertime: Comfort Classics, Freezer Food, 16-Minute Meals, and Other Delicious Ways to Solve Supper!', 'price': 'Â£56.41', 'availability': 'In stock'}
# {'title': 'The Past Never Ends', 'price': 'Â£56.50', 'availability': 'In stock'}
# {'title': 'The Natural History of Us (The Fine Art of Pretending #2)', 'price': 'Â£45.22', 'availability': 'In stock'}
# {'title': 'The Nameless City (The Nameless City #1)', 'price': 'Â£38.16', 'availability': 'In stock'}
# {'title': 'The Murder That Never Was (Forensic Instincts #5)', 'price': 'Â£54.11', 'availability': 'In stock'}
# {'title': "The Most Perfect Thing: Inside (and Outside) a Bird's Egg", 'price': 'Â£42.96', 'availability': 'In stock'}
# {'title': 'The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy', 'price': 'Â£23.89', 'availability': 'In stock'}
# {'title': 'The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing', 'price': 'Â£16.77', 'availability': 'In stock'}
# {'title': 'The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer', 'price': 'Â£20.59', 'availability': 'In stock'}
# {'title': 'The Gutsy Girl: Escapades for Your Life of Epic Adventure', 'price': 'Â£37.13', 'availability': 'In stock'}
# {'title': 'The Electric Pencil: Drawings from Inside State Hospital No. 3', 'price': 'Â£56.06', 'availability': 'In stock'}
# {'title': 'The Death of Humanity: and the Case for Life', 'price': 'Â£58.11', 'availability': 'In stock'}
# {'title': 'The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life', 'price': 'Â£49.05', 'availability': 'In stock'}
# {'title': 'The Art Forger', 'price': 'Â£40.76', 'availability': 'In stock'}
# {'title': 'The Age of Genius: The Seventeenth Century and the Birth of the Modern Mind', 'price': 'Â£19.73', 'availability': 'In stock'}
# {'title': "The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution", 'price': 'Â£32.24', 'availability': 'In stock'}
# {'title': 'Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up', 'price': 'Â£41.83', 'availability': 'In stock'}
# {'title': 'Soul Reader', 'price': 'Â£39.58', 'availability': 'In stock'}
# {'title': 'Security', 'price': 'Â£39.25', 'availability': 'In stock'}
# {'title': 'Saga, Volume 6 (Saga (Collected Editions) #6)', 'price': 'Â£25.02', 'availability': 'In stock'}
# {'title': 'Saga, Volume 5 (Saga (Collected Editions) #5)', 'price': 'Â£51.04', 'availability': 'In stock'}
# {'title': 'Reskilling America: Learning to Labor in the Twenty-First Century', 'price': 'Â£19.83', 'availability': 'In stock'}
# {'title': 'Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) #11-15)', 'price': 'Â£50.40', 'availability': 'In stock'}
# {'title': 'Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)', 'price': 'Â£13.61', 'availability': 'In stock'}
# {'title': 'Princess Between Worlds (Wide-Awake Princess #5)', 'price': 'Â£13.34', 'availability': 'In stock'}
# {'title': 'Pop Gun War, Volume 1: Gift', 'price': 'Â£18.97', 'availability': 'In stock'}
# {'title': 'Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics', 'price': 'Â£36.28', 'availability': 'In stock'}
# {'title': 'Patience', 'price': 'Â£10.16', 'availability': 'In stock'}
# {'title': 'Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)', 'price': 'Â£15.44', 'availability': 'In stock'}
# {'title': 'orange: The Complete Collection 1 (orange: The Complete Collection #1)', 'price': 'Â£48.41', 'availability': 'In stock'}
# {'title': 'Online Marketing for Busy Authors: A Step-By-Step Guide', 'price': 'Â£46.35', 'availability': 'In stock'}
# {'title': 'On a Midnight Clear', 'price': 'Â£14.07', 'availability': 'In stock'}
# {'title': 'Obsidian (Lux #1)', 'price': 'Â£14.86', 'availability': 'In stock'}
# {'title': 'My Paris Kitchen: Recipes and Stories', 'price': 'Â£33.37', 'availability': 'In stock'}
# {'title': 'Masks and Shadows', 'price': 'Â£56.40', 'availability': 'In stock'}
# {'title': 'Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed', 'price': 'Â£14.02', 'availability': 'In stock'}
# {'title': 'Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)', 'price': 'Â£46.91', 'availability': 'In stock'}
# {'title': 'Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)', 'price': 'Â£45.61', 'availability': 'In stock'}
# {'title': 'Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)', 'price': 'Â£19.92', 'availability': 'In stock'}
# {'title': 'Layered: Baking, Building, and Styling Spectacular Cakes', 'price': 'Â£40.11', 'availability': 'In stock'}
# {'title': 'Judo: Seven Steps to Black Belt (an Introductory Guide for Beginners)', 'price': 'Â£53.90', 'availability': 'In stock'}
# {'title': 'Join', 'price': 'Â£35.67', 'availability': 'In stock'}
# {'title': 'In the Country We Love: My Family Divided', 'price': 'Â£22.00', 'availability': 'In stock'}
# {'title': 'Immunity: How Elie Metchnikoff Changed the Course of Modern Medicine', 'price': 'Â£57.36', 'availability': 'In stock'}
# {'title': 'I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland (Compilations) #1-5)', 'price': 'Â£29.17', 'availability': 'In stock'}
# {'title': 'I am a Hero Omnibus Volume 1', 'price': 'Â£54.63', 'availability': 'In stock'}
# {'title': 'How to Be Miserable: 40 Strategies You Already Use', 'price': 'Â£46.03', 'availability': 'In stock'}
# {'title': 'Her Backup Boyfriend (The Sorensen Family #1)', 'price': 'Â£33.97', 'availability': 'In stock'}
# {'title': 'Giant Days, Vol. 2 (Giant Days #5-8)', 'price': 'Â£22.11', 'availability': 'In stock'}
# {'title': 'Forever and Forever: The Courtship of Henry Longfellow and Fanny Appleton', 'price': 'Â£29.69', 'availability': 'In stock'}
# {'title': 'First and First (Five Boroughs #3)', 'price': 'Â£15.97', 'availability': 'In stock'}
# {'title': 'Fifty Shades Darker (Fifty Shades #2)', 'price': 'Â£21.96', 'availability': 'In stock'}
# {'title': 'Everydata: The Misinformation Hidden in the Little Data You Consume Every Day', 'price': 'Â£54.35', 'availability': 'In stock'}
# {'title': "Don't Be a Jerk: And Other Practical Advice from Dogen, Japan's Greatest Zen Master", 'price': 'Â£37.97', 'availability': 'In stock'}
# {'title': 'Danganronpa Volume 1', 'price': 'Â£51.99', 'availability': 'In stock'}
# {'title': 'Crown of Midnight (Throne of Glass #2)', 'price': 'Â£43.29', 'availability': 'In stock'}
# {'title': 'Codename Baboushka, Volume 1: The Conclave of Death', 'price': 'Â£36.72', 'availability': 'In stock'}
# {'title': 'Camp Midnight', 'price': 'Â£17.08', 'availability': 'In stock'}
# {'title': 'Call the Nurse: True Stories of a Country Nurse on a Scottish Isle', 'price': 'Â£29.14', 'availability': 'In stock'}
# {'title': 'Burning', 'price': 'Â£28.81', 'availability': 'In stock'}
# {'title': 'Bossypants', 'price': 'Â£49.46', 'availability': 'In stock'}
# {'title': 'Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet (Collected Editions))', 'price': 'Â£37.92', 'availability': 'In stock'}
# {'title': 'Avatar: The Last Airbender: Smoke and Shadow, Part 3 (Smoke and Shadow #3)', 'price': 'Â£28.09', 'availability': 'In stock'}
# {'title': 'Algorithms to Live By: The Computer Science of Human Decisions', 'price': 'Â£30.81', 'availability': 'In stock'}
# {'title': 'A World of Flavor: Your Gluten Free Passport', 'price': 'Â£42.95', 'availability': 'In stock'}
# {'title': 'A Piece of Sky, a Grain of Rice: A Memoir in Four Meditations', 'price': 'Â£56.76', 'availability': 'In stock'}
# {'title': 'A Murder in Time', 'price': 'Â£16.64', 'availability': 'In stock'}
# {'title': 'A Flight of Arrows (The Pathfinders #2)', 'price': 'Â£55.53', 'availability': 'In stock'}
# {'title': 'A Fierce and Subtle Poison', 'price': 'Â£28.13', 'availability': 'In stock'}
# {'title': 'A Court of Thorns and Roses (A Court of Thorns and Roses #1)', 'price': 'Â£52.37', 'availability': 'In stock'}
# {'title': '(Un)Qualified: How God Uses Broken People to Do Big Things', 'price': 'Â£54.00', 'availability': 'In stock'}
# {'title': 'You Are What You Love: The Spiritual Power of Habit', 'price': 'Â£21.87', 'availability': 'In stock'}
# {'title': "William Shakespeare's Star Wars: Verily, A New Hope (William Shakespeare's Star Wars #4)", 'price': 'Â£43.30', 'availability': 'In stock'}
# {'title': 'Tuesday Nights in 1980', 'price': 'Â£21.04', 'availability': 'In stock'}
# {'title': 'Tracing Numbers on a Train', 'price': 'Â£41.60', 'availability': 'In stock'}
# {'title': 'Throne of Glass (Throne of Glass #1)', 'price': 'Â£35.07', 'availability': 'In stock'}
# {'title': 'Thomas Jefferson and the Tripoli Pirates: The Forgotten War That Changed American History', 'price': 'Â£59.64', 'availability': 'In stock'}
# {'title': 'Thirteen Reasons Why', 'price': 'Â£52.72', 'availability': 'In stock'}
# {'title': 'The White Cat and the Monk: A Retelling of the Poem â\x80\x9cPangur BÃ¡nâ\x80\x9d', 'price': 'Â£58.08', 'availability': 'In stock'}
# {'title': 'The Wedding Dress', 'price': 'Â£24.12', 'availability': 'In stock'}
# {'title': 'The Vacationers', 'price': 'Â£42.15', 'availability': 'In stock'}
# {'title': 'The Third Wave: An Entrepreneurâ\x80\x99s Vision of the Future', 'price': 'Â£12.61', 'availability': 'In stock'}
# {'title': 'The Stranger', 'price': 'Â£17.44', 'availability': 'In stock'}
# {'title': 'The Shadow Hero (The Shadow Hero)', 'price': 'Â£33.14', 'availability': 'In stock'}
# {'title': 'The Secret (The Secret #1)', 'price': 'Â£27.37', 'availability': 'In stock'}
# {'title': 'The Regional Office Is Under Attack!', 'price': 'Â£51.36', 'availability': 'In stock'}
# {'title': 'The Psychopath Test: A Journey Through the Madness Industry', 'price': 'Â£36.00', 'availability': 'In stock'}
# {'title': 'The Project', 'price': 'Â£10.65', 'availability': 'In stock'}
# {'title': 'The Power of Now: A Guide to Spiritual Enlightenment', 'price': 'Â£43.54', 'availability': 'In stock'}
# {'title': "The Omnivore's Dilemma: A Natural History of Four Meals", 'price': 'Â£38.21', 'availability': 'In stock'}
# {'title': 'The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us', 'price': 'Â£37.34', 'availability': 'In stock'}
# {'title': 'The Murder of Roger Ackroyd (Hercule Poirot #4)', 'price': 'Â£44.10', 'availability': 'In stock'}
# {'title': 'The Mistake (Off-Campus #2)', 'price': 'Â£43.29', 'availability': 'In stock'}
# {'title': "The Matchmaker's Playbook (Wingmen Inc. #1)", 'price': 'Â£55.85', 'availability': 'In stock'}
# {'title': 'The Love and Lemons Cookbook: An Apple-to-Zucchini Celebration of Impromptu Cooking', 'price': 'Â£37.60', 'availability': 'In stock'}
# {'title': 'The Long Shadow of Small Ghosts: Murder and Memory in an American City', 'price': 'Â£10.97', 'availability': 'In stock'}
# {'title': 'The Kite Runner', 'price': 'Â£41.82', 'availability': 'In stock'}
# {'title': 'The House by the Lake', 'price': 'Â£36.95', 'availability': 'In stock'}
# {'title': 'The Glittering Court (The Glittering Court #1)', 'price': 'Â£44.28', 'availability': 'In stock'}
# {'title': 'The Girl on the Train', 'price': 'Â£55.02', 'availability': 'In stock'}
# {'title': 'The Genius of Birds', 'price': 'Â£17.24', 'availability': 'In stock'}
# {'title': 'The Emerald Mystery', 'price': 'Â£23.15', 'availability': 'In stock'}
# {'title': 'The Cookies & Cups Cookbook: 125+ sweet & savory recipes reminding you to Always Eat Dessert First', 'price': 'Â£41.25', 'availability': 'In stock'}
# {'title': "The Bridge to Consciousness: I'm Writing the Bridge Between Science and Our Old and New Beliefs.", 'price': 'Â£32.00', 'availability': 'In stock'}
# {'title': "The Artist's Way: A Spiritual Path to Higher Creativity", 'price': 'Â£38.49', 'availability': 'In stock'}
# {'title': 'The Art of War', 'price': 'Â£33.34', 'availability': 'In stock'}
# {'title': 'The Argonauts', 'price': 'Â£10.93', 'availability': 'In stock'}
# {'title': 'The 10% Entrepreneur: Live Your Startup Dream Without Quitting Your Day Job', 'price': 'Â£27.55', 'availability': 'In stock'}
# {'title': 'Suddenly in Love (Lake Haven #1)', 'price': 'Â£55.99', 'availability': 'In stock'}
# {'title': 'Something More Than This', 'price': 'Â£16.24', 'availability': 'In stock'}
# {'title': 'Soft Apocalypse', 'price': 'Â£26.12', 'availability': 'In stock'}
# {'title': "So You've Been Publicly Shamed", 'price': 'Â£12.23', 'availability': 'In stock'}
# {'title': 'Shoe Dog: A Memoir by the Creator of NIKE', 'price': 'Â£23.99', 'availability': 'In stock'}
# {'title': 'Shobu Samurai, Project Aryoku (#3)', 'price': 'Â£29.06', 'availability': 'In stock'}
# {'title': 'Secrets and Lace (Fatal Hearts #1)', 'price': 'Â£20.27', 'availability': 'In stock'}
# {'title': 'Scarlett Epstein Hates It Here', 'price': 'Â£43.55', 'availability': 'In stock'}
# {'title': 'Romero and Juliet: A Tragic Tale of Love and Zombies', 'price': 'Â£36.94', 'availability': 'In stock'}
# {'title': 'Redeeming Love', 'price': 'Â£20.47', 'availability': 'In stock'}
# {'title': 'Poses for Artists Volume 1 - Dynamic and Sitting Poses: An Essential Reference for Figure Drawing and the Human Form', 'price': 'Â£41.06', 'availability': 'In stock'}
# {'title': 'Poems That Make Grown Women Cry', 'price': 'Â£14.19', 'availability': 'In stock'}
# {'title': 'Nightingale, Sing', 'price': 'Â£38.28', 'availability': 'In stock'}
# {'title': 'Night Sky with Exit Wounds', 'price': 'Â£41.05', 'availability': 'In stock'}
# {'title': 'Mrs. Houdini', 'price': 'Â£30.25', 'availability': 'In stock'}
# {'title': 'Modern Romance', 'price': 'Â£28.26', 'availability': 'In stock'}
# {'title': 'Miss Peregrineâ\x80\x99s Home for Peculiar Children (Miss Peregrineâ\x80\x99s Peculiar Children #1)', 'price': 'Â£10.76', 'availability': 'In stock'}
# {'title': 'Louisa: The Extraordinary Life of Mrs. Adams', 'price': 'Â£16.85', 'availability': 'In stock'}
# {'title': 'Little Red', 'price': 'Â£13.47', 'availability': 'In stock'}
# {'title': 'Library of Souls (Miss Peregrineâ\x80\x99s Peculiar Children #3)', 'price': 'Â£48.56', 'availability': 'In stock'}
# {'title': 'Large Print Heart of the Pride', 'price': 'Â£19.15', 'availability': 'In stock'}
# {'title': 'I Had a Nice Time And Other Lies...: How to find love & sh*t like that', 'price': 'Â£57.36', 'availability': 'In stock'}
# {'title': 'Hollow City (Miss Peregrineâ\x80\x99s Peculiar Children #2)', 'price': 'Â£42.98', 'availability': 'In stock'}
# {'title': 'Grumbles', 'price': 'Â£22.16', 'availability': 'In stock'}
# {'title': 'Full Moon over Noahâ\x80\x99s Ark: An Odyssey to Mount Ararat and Beyond', 'price': 'Â£49.43', 'availability': 'In stock'}
# {'title': 'Frostbite (Vampire Academy #2)', 'price': 'Â£29.99', 'availability': 'In stock'}
# {'title': 'Follow You Home', 'price': 'Â£21.36', 'availability': 'In stock'}
# {'title': 'First Steps for New Christians (Print Edition)', 'price': 'Â£29.00', 'availability': 'In stock'}
# {'title': 'Finders Keepers (Bill Hodges Trilogy #2)', 'price': 'Â£53.53', 'availability': 'In stock'}
# {'title': 'Fables, Vol. 1: Legends in Exile (Fables #1)', 'price': 'Â£41.62', 'availability': 'In stock'}
# {'title': 'Eureka Trivia 6.0', 'price': 'Â£54.59', 'availability': 'In stock'}
# {'title': 'Drive: The Surprising Truth About What Motivates Us', 'price': 'Â£34.95', 'availability': 'In stock'}
# {'title': 'Done Rubbed Out (Reightman & Bailey #1)', 'price': 'Â£37.72', 'availability': 'In stock'}
# {'title': 'Doing It Over (Most Likely To #1)', 'price': 'Â£35.61', 'availability': 'In stock'}
# {'title': 'Deliciously Ella Every Day: Quick and Easy Recipes for Gluten-Free Snacks, Packed Lunches, and Simple Meals', 'price': 'Â£42.16', 'availability': 'In stock'}
# {'title': 'Dark Notes', 'price': 'Â£19.19', 'availability': 'In stock'}
# {'title': 'Daring Greatly: How the Courage to Be Vulnerable Transforms the Way We Live, Love, Parent, and Lead', 'price': 'Â£19.43', 'availability': 'In stock'}
# {'title': 'Close to You', 'price': 'Â£49.46', 'availability': 'In stock'}
# {'title': 'Chasing Heaven: What Dying Taught Me About Living', 'price': 'Â£37.80', 'availability': 'In stock'}
# {'title': 'Big Magic: Creative Living Beyond Fear', 'price': 'Â£30.80', 'availability': 'In stock'}
# {'title': 'Becoming Wise: An Inquiry into the Mystery and Art of Living', 'price': 'Â£27.43', 'availability': 'In stock'}
# {'title': 'Beauty Restored (Riley Family Legacy Novellas #3)', 'price': 'Â£11.11', 'availability': 'In stock'}
# {'title': 'Batman: The Long Halloween (Batman)', 'price': 'Â£36.50', 'availability': 'In stock'}
# {'title': 'Batman: The Dark Knight Returns (Batman)', 'price': 'Â£15.38', 'availability': 'In stock'}
# {'title': "Ayumi's Violin", 'price': 'Â£15.48', 'availability': 'In stock'}
# {'title': 'Anonymous', 'price': 'Â£46.82', 'availability': 'In stock'}
# {'title': 'Amy Meets the Saints and Sages', 'price': 'Â£18.46', 'availability': 'In stock'}
# {'title': 'Amid the Chaos', 'price': 'Â£36.58', 'availability': 'In stock'}
# {'title': 'Amatus', 'price': 'Â£50.54', 'availability': 'In stock'}
# {'title': 'Agnostic: A Spirited Manifesto', 'price': 'Â£12.51', 'availability': 'In stock'}
# {'title': 'Zealot: The Life and Times of Jesus of Nazareth', 'price': 'Â£24.70', 'availability': 'In stock'}
# {'title': 'You (You #1)', 'price': 'Â£43.61', 'availability': 'In stock'}
# {'title': 'Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1)', 'price': 'Â£37.34', 'availability': 'In stock'}
# {'title': 'Wild Swans', 'price': 'Â£14.36', 'availability': 'In stock'}
# {'title': 'Why the Right Went Wrong: Conservatism--From Goldwater to the Tea Party and Beyond', 'price': 'Â£52.65', 'availability': 'In stock'}
# {'title': 'Whole Lotta Creativity Going On: 60 Fun and Unusual Exercises to Awaken and Strengthen Your Creativity', 'price': 'Â£38.20', 'availability': 'In stock'}
# {'title': "What's It Like in Space?: Stories from Astronauts Who've Been There", 'price': 'Â£19.60', 'availability': 'In stock'}
# {'title': 'We Are Robin, Vol. 1: The Vigilante Business (We Are Robin #1)', 'price': 'Â£53.90', 'availability': 'In stock'}
# {'title': "Walt Disney's Alice in Wonderland", 'price': 'Â£12.96', 'availability': 'In stock'}
# {'title': 'V for Vendetta (V for Vendetta Complete)', 'price': 'Â£37.10', 'availability': 'In stock'}
# {'title': 'Until Friday Night (The Field Party #1)', 'price': 'Â£46.31', 'availability': 'In stock'}
# {'title': 'Unbroken: A World War II Story of Survival, Resilience, and Redemption', 'price': 'Â£45.95', 'availability': 'In stock'}
# {'title': 'Twenty Yawns', 'price': 'Â£22.08', 'availability': 'In stock'}
# {'title': 'Through the Woods', 'price': 'Â£25.38', 'availability': 'In stock'}
# {'title': 'This Is Where It Ends', 'price': 'Â£27.12', 'availability': 'In stock'}
# {'title': 'The Year of Magical Thinking', 'price': 'Â£43.04', 'availability': 'In stock'}
# {'title': 'The Wright Brothers', 'price': 'Â£56.80', 'availability': 'In stock'}
# {'title': "The White Queen (The Cousins' War #1)", 'price': 'Â£25.91', 'availability': 'In stock'}
# {'title': "The Wedding Pact (The O'Malleys #2)", 'price': 'Â£32.61', 'availability': 'In stock'}
# {'title': 'The Time Keeper', 'price': 'Â£27.88', 'availability': 'In stock'}
# {'title': 'The Testament of Mary', 'price': 'Â£52.67', 'availability': 'In stock'}
# {'title': 'The Star-Touched Queen', 'price': 'Â£46.02', 'availability': 'In stock'}
# {'title': 'The Songs of the Gods', 'price': 'Â£44.48', 'availability': 'In stock'}
# {'title': 'The Song of Achilles', 'price': 'Â£37.40', 'availability': 'In stock'}
# {'title': 'The Rosie Project (Don Tillman #1)', 'price': 'Â£54.04', 'availability': 'In stock'}
# {'title': 'The Power of Habit: Why We Do What We Do in Life and Business', 'price': 'Â£16.88', 'availability': 'In stock'}
# {'title': 'The Marriage of Opposites', 'price': 'Â£28.08', 'availability': 'In stock'}
# {'title': 'The Lucifer Effect: Understanding How Good People Turn Evil', 'price': 'Â£10.40', 'availability': 'In stock'}
# {'title': 'The Long Haul (Diary of a Wimpy Kid #9)', 'price': 'Â£44.07', 'availability': 'In stock'}
# {'title': 'The Loney', 'price': 'Â£23.40', 'availability': 'In stock'}
# {'title': 'The Literature Book (Big Ideas Simply Explained)', 'price': 'Â£17.43', 'availability': 'In stock'}
# {'title': 'The Last Mile (Amos Decker #2)', 'price': 'Â£54.21', 'availability': 'In stock'}
# {'title': 'The Immortal Life of Henrietta Lacks', 'price': 'Â£40.67', 'availability': 'In stock'}
# {'title': 'The Hidden Oracle (The Trials of Apollo #1)', 'price': 'Â£52.26', 'availability': 'In stock'}
# {'title': 'The Help Yourself Cookbook for Kids: 60 Easy Plant-Based Recipes Kids Can Make to Stay Healthy and Save the Earth', 'price': 'Â£28.77', 'availability': 'In stock'}
# {'title': 'The Guilty (Will Robie #4)', 'price': 'Â£13.82', 'availability': 'In stock'}
# {'title': 'The First Hostage (J.B. Collins #2)', 'price': 'Â£25.85', 'availability': 'In stock'}
# {'title': 'The Dovekeepers', 'price': 'Â£48.78', 'availability': 'In stock'}
# {'title': 'The Darkest Lie', 'price': 'Â£35.35', 'availability': 'In stock'}
# {'title': 'The Bane Chronicles (The Bane Chronicles #1-11)', 'price': 'Â£44.73', 'availability': 'In stock'}
# {'title': 'The Bad-Ass Librarians of Timbuktu: And Their Race to Save the Worldâ\x80\x99s Most Precious Manuscripts', 'price': 'Â£15.77', 'availability': 'In stock'}
# {'title': 'The 14th Colony (Cotton Malone #11)', 'price': 'Â£39.24', 'availability': 'In stock'}
# {'title': 'That Darkness (Gardiner and Renner #1)', 'price': 'Â£13.92', 'availability': 'In stock'}
# {'title': 'Tastes Like Fear (DI Marnie Rome #3)', 'price': 'Â£10.69', 'availability': 'In stock'}
# {'title': 'Take Me with You', 'price': 'Â£45.21', 'availability': 'In stock'}
# {'title': 'Swell: A Year of Waves', 'price': 'Â£45.58', 'availability': 'In stock'}
# {'title': 'Superman Vol. 1: Before Truth (Superman by Gene Luen Yang #1)', 'price': 'Â£11.89', 'availability': 'In stock'}
# {'title': 'Still Life with Bread Crumbs', 'price': 'Â£26.41', 'availability': 'In stock'}
# {'title': 'Steve Jobs', 'price': 'Â£39.50', 'availability': 'In stock'}
# {'title': 'Sorting the Beef from the Bull: The Science of Food Fraud Forensics', 'price': 'Â£44.74', 'availability': 'In stock'}
# {'title': 'Someone Like You (The Harrisons #2)', 'price': 'Â£52.79', 'availability': 'In stock'}
# {'title': 'So Cute It Hurts!!, Vol. 6 (So Cute It Hurts!! #6)', 'price': 'Â£35.43', 'availability': 'In stock'}
# {'title': 'Shtum', 'price': 'Â£55.84', 'availability': 'In stock'}
# {'title': 'See America: A Celebration of Our National Parks & Treasured Sites', 'price': 'Â£48.87', 'availability': 'In stock'}
# {'title': 'salt.', 'price': 'Â£46.78', 'availability': 'In stock'}
# {'title': 'Robin War', 'price': 'Â£47.82', 'availability': 'In stock'}
# {'title': 'Red Hood/Arsenal, Vol. 1: Open for Business (Red Hood/Arsenal #1)', 'price': 'Â£25.48', 'availability': 'In stock'}
# {'title': 'Rain Fish', 'price': 'Â£23.57', 'availability': 'In stock'}
# {'title': 'Quarter Life Poetry: Poems for the Young, Broke and Hangry', 'price': 'Â£50.89', 'availability': 'In stock'}
# {'title': 'Pet Sematary', 'price': 'Â£10.56', 'availability': 'In stock'}
# {'title': 'Overload: How to Unplug, Unwind, and Unleash Yourself from the Pressure of Stress', 'price': 'Â£52.15', 'availability': 'In stock'}
# {'title': 'Once Was a Time', 'price': 'Â£18.28', 'availability': 'In stock'}
# {'title': 'Old School (Diary of a Wimpy Kid #10)', 'price': 'Â£11.83', 'availability': 'In stock'}
# {'title': 'No Dream Is Too High: Life Lessons From a Man Who Walked on the Moon', 'price': 'Â£21.95', 'availability': 'In stock'}
# {'title': 'Naruto (3-in-1 Edition), Vol. 14: Includes Vols. 40, 41 & 42 (Naruto: Omnibus #14)', 'price': 'Â£38.39', 'availability': 'In stock'}
# {'title': 'My Name Is Lucy Barton', 'price': 'Â£41.56', 'availability': 'In stock'}
# {'title': 'My Mrs. Brown', 'price': 'Â£24.48', 'availability': 'In stock'}
# {'title': 'My Kind of Crazy', 'price': 'Â£40.36', 'availability': 'In stock'}
# {'title': 'Mr. Mercedes (Bill Hodges Trilogy #1)', 'price': 'Â£28.90', 'availability': 'In stock'}
# {'title': 'More Than Music (Chasing the Dream #1)', 'price': 'Â£37.61', 'availability': 'In stock'}
# {'title': 'Made to Stick: Why Some Ideas Survive and Others Die', 'price': 'Â£38.85', 'availability': 'In stock'}
# {'title': 'Luis Paints the World', 'price': 'Â£53.95', 'availability': 'In stock'}
# {'title': 'Luckiest Girl Alive', 'price': 'Â£49.83', 'availability': 'In stock'}
# {'title': 'Lowriders to the Center of the Earth (Lowriders in Space #2)', 'price': 'Â£51.51', 'availability': 'In stock'}
# {'title': 'Love Is a Mix Tape (Music #1)', 'price': 'Â£18.03', 'availability': 'In stock'}
# {'title': 'Looking for Lovely: Collecting the Moments that Matter', 'price': 'Â£29.14', 'availability': 'In stock'}
# {'title': 'Living Leadership by Insight: A Good Leader Achieves, a Great Leader Builds Monuments', 'price': 'Â£46.91', 'availability': 'In stock'}
# {'title': 'Let It Out: A Journey Through Journaling', 'price': 'Â£26.79', 'availability': 'In stock'}
# {'title': 'Lady Midnight (The Dark Artifices #1)', 'price': 'Â£16.28', 'availability': 'In stock'}
# {'title': "It's All Easy: Healthy, Delicious Weeknight Meals in under 30 Minutes", 'price': 'Â£19.55', 'availability': 'In stock'}
# {'title': 'Island of Dragons (Unwanteds #7)', 'price': 'Â£29.65', 'availability': 'In stock'}
# {'title': "I Know What I'm Doing -- and Other Lies I Tell Myself: Dispatches from a Life Under Construction", 'price': 'Â£25.98', 'availability': 'In stock'}
# {'title': 'I Am Pilgrim (Pilgrim #1)', 'price': 'Â£10.60', 'availability': 'In stock'}
# {'title': 'Hyperbole and a Half: Unfortunate Situations, Flawed Coping Mechanisms, Mayhem, and Other Things That Happened', 'price': 'Â£14.75', 'availability': 'In stock'}
# {'title': 'Hush, Hush (Hush, Hush #1)', 'price': 'Â£47.02', 'availability': 'In stock'}
# {'title': 'Hold Your Breath (Search and Rescue #1)', 'price': 'Â£28.82', 'availability': 'In stock'}
# {'title': 'Hamilton: The Revolution', 'price': 'Â£58.79', 'availability': 'In stock'}
# {'title': 'Greek Mythic History', 'price': 'Â£10.23', 'availability': 'In stock'}
# {'title': 'God: The Most Unpleasant Character in All Fiction', 'price': 'Â£30.03', 'availability': 'In stock'}
# {'title': 'Glory over Everything: Beyond The Kitchen House', 'price': 'Â£45.84', 'availability': 'In stock'}
# {'title': 'Feathers: Displays of Brilliant Plumage', 'price': 'Â£49.05', 'availability': 'In stock'}
# {'title': 'Far & Away: Places on the Brink of Change: Seven Continents, Twenty-Five Years', 'price': 'Â£15.06', 'availability': 'In stock'}
# {'title': 'Every Last Word', 'price': 'Â£46.47', 'availability': 'In stock'}
# {'title': 'Eligible (The Austen Project #4)', 'price': 'Â£27.09', 'availability': 'In stock'}
# {'title': 'El Deafo', 'price': 'Â£57.62', 'availability': 'In stock'}
# {'title': 'Eight Hundred Grapes', 'price': 'Â£14.39', 'availability': 'In stock'}
# {'title': 'Eaternity: More than 150 Deliciously Easy Vegan Recipes for a Long, Healthy, Satisfied, Joyful Life', 'price': 'Â£51.75', 'availability': 'In stock'}
# {'title': 'Eat Fat, Get Thin', 'price': 'Â£54.07', 'availability': 'In stock'}
# {'title': "Don't Get Caught", 'price': 'Â£55.35', 'availability': 'In stock'}
# {'title': 'Doctor Sleep (The Shining #2)', 'price': 'Â£40.12', 'availability': 'In stock'}
# {'title': 'Demigods & Magicians: Percy and Annabeth Meet the Kanes (Percy Jackson & Kane Chronicles Crossover #1-3)', 'price': 'Â£37.51', 'availability': 'In stock'}
# {'title': 'Dear Mr. Knightley', 'price': 'Â£11.21', 'availability': 'In stock'}
# {'title': 'Daily Fantasy Sports', 'price': 'Â£36.58', 'availability': 'In stock'}
# {'title': 'Crazy Love: Overwhelmed by a Relentless God', 'price': 'Â£47.72', 'availability': 'In stock'}
# {'title': 'Cometh the Hour (The Clifton Chronicles #6)', 'price': 'Â£25.01', 'availability': 'In stock'}
# {'title': 'Code Name Verity (Code Name Verity #1)', 'price': 'Â£22.13', 'availability': 'In stock'}
# {'title': 'Clockwork Angel (The Infernal Devices #1)', 'price': 'Â£44.14', 'availability': 'In stock'}
# {'title': 'City of Glass (The Mortal Instruments #3)', 'price': 'Â£56.02', 'availability': 'In stock'}
# {'title': 'City of Fallen Angels (The Mortal Instruments #4)', 'price': 'Â£11.23', 'availability': 'In stock'}
# {'title': 'City of Bones (The Mortal Instruments #1)', 'price': 'Â£43.28', 'availability': 'In stock'}
# {'title': 'City of Ashes (The Mortal Instruments #2)', 'price': 'Â£47.27', 'availability': 'In stock'}
# {'title': 'Cell', 'price': 'Â£20.29', 'availability': 'In stock'}
# {'title': 'Catching Jordan (Hundred Oaks)', 'price': 'Â£50.83', 'availability': 'In stock'}
# {'title': 'Carry On, Warrior: Thoughts on Life Unarmed', 'price': 'Â£31.85', 'availability': 'In stock'}
# {'title': 'Carrie', 'price': 'Â£46.23', 'availability': 'In stock'}
# {'title': 'Buying In: The Secret Dialogue Between What We Buy and Who We Are', 'price': 'Â£37.80', 'availability': 'In stock'}
# {'title': 'Brain on Fire: My Month of Madness', 'price': 'Â£49.32', 'availability': 'In stock'}
# {'title': 'Batman: Europa', 'price': 'Â£32.01', 'availability': 'In stock'}
# {'title': 'Barefoot Contessa Back to Basics', 'price': 'Â£28.01', 'availability': 'In stock'}
# {'title': "Barefoot Contessa at Home: Everyday Recipes You'll Make Over and Over Again", 'price': 'Â£50.62', 'availability': 'In stock'}
# {'title': 'Balloon Animals', 'price': 'Â£17.03', 'availability': 'In stock'}
# {'title': 'Art Ops Vol. 1', 'price': 'Â£48.80', 'availability': 'In stock'}
# {'title': 'Aristotle and Dante Discover the Secrets of the Universe (Aristotle and Dante Discover the Secrets of the Universe #1)', 'price': 'Â£58.14', 'availability': 'In stock'}
# {'title': 'Angels Walking (Angels Walking #1)', 'price': 'Â£34.20', 'availability': 'In stock'}
# {'title': 'Angels & Demons (Robert Langdon #1)', 'price': 'Â£51.48', 'availability': 'In stock'}
# {'title': 'All the Light We Cannot See', 'price': 'Â£29.87', 'availability': 'In stock'}
# {'title': 'Adulthood Is a Myth: A "Sarah\'s Scribbles" Collection', 'price': 'Â£10.90', 'availability': 'In stock'}
# {'title': 'Abstract City', 'price': 'Â£56.37', 'availability': 'In stock'}
# {'title': 'A Time of Torment (Charlie Parker #14)', 'price': 'Â£48.35', 'availability': 'In stock'}
# {'title': 'A Study in Scarlet (Sherlock Holmes #1)', 'price': 'Â£16.73', 'availability': 'In stock'}
# {'title': 'A Series of Catastrophes and Miracles: A True Story of Love, Science, and Cancer', 'price': 'Â£56.48', 'availability': 'In stock'}
# {'title': "A People's History of the United States", 'price': 'Â£40.79', 'availability': 'In stock'}
# {'title': 'A Man Called Ove', 'price': 'Â£39.72', 'availability': 'In stock'}
# {'title': 'A Distant Mirror: The Calamitous 14th Century', 'price': 'Â£14.58', 'availability': 'In stock'}
# {'title': 'A Brush of Wings (Angels Walking #3)', 'price': 'Â£55.51', 'availability': 'In stock'}
# {'title': '1491: New Revelations of the Americas Before Columbus', 'price': 'Â£21.80', 'availability': 'In stock'}
# {'title': 'The Three Searches, Meaning, and the Story', 'price': 'Â£13.33', 'availability': 'In stock'}
# {'title': 'Searching for Meaning in Gailana', 'price': 'Â£38.73', 'availability': 'In stock'}
# {'title': 'Rook', 'price': 'Â£37.86', 'availability': 'In stock'}
# {'title': 'My Kitchen Year: 136 Recipes That Saved My Life', 'price': 'Â£11.53', 'availability': 'In stock'}
# {'title': '13 Hours: The Inside Account of What Really Happened In Benghazi', 'price': 'Â£27.06', 'availability': 'In stock'}
# {'title': "Will You Won't You Want Me?", 'price': 'Â£13.86', 'availability': 'In stock'}
# {'title': 'Tipping Point for Planet Earth: How Close Are We to the Edge?', 'price': 'Â£37.55', 'availability': 'In stock'}
# {'title': 'The Star-Touched Queen', 'price': 'Â£32.30', 'availability': 'In stock'}
# {'title': 'The Silent Sister (Riley MacPherson #1)', 'price': 'Â£46.29', 'availability': 'In stock'}
# {'title': 'The Midnight Watch: A Novel of the Titanic and the Californian', 'price': 'Â£26.20', 'availability': 'In stock'}
# {'title': 'The Lonely City: Adventures in the Art of Being Alone', 'price': 'Â£33.26', 'availability': 'In stock'}
# {'title': 'The Gray Rhino: How to Recognize and Act on the Obvious Dangers We Ignore', 'price': 'Â£59.15', 'availability': 'In stock'}
# {'title': 'The Golden Condom: And Other Essays on Love Lost and Found', 'price': 'Â£39.43', 'availability': 'In stock'}
# {'title': 'The Epidemic (The Program 0.6)', 'price': 'Â£14.44', 'availability': 'In stock'}
# {'title': 'The Dinner Party', 'price': 'Â£56.54', 'availability': 'In stock'}
# {'title': 'The Diary of a Young Girl', 'price': 'Â£59.90', 'availability': 'In stock'}
# {'title': 'The Children', 'price': 'Â£11.88', 'availability': 'In stock'}
# {'title': 'Stars Above (The Lunar Chronicles #4.5)', 'price': 'Â£48.05', 'availability': 'In stock'}
# {'title': 'Snatched: How A Drug Queen Went Undercover for the DEA and Was Kidnapped By Colombian Guerillas', 'price': 'Â£21.21', 'availability': 'In stock'}
# {'title': 'Raspberry Pi Electronics Projects for the Evil Genius', 'price': 'Â£49.67', 'availability': 'In stock'}
# {'title': 'Quench Your Own Thirst: Business Lessons Learned Over a Beer or Two', 'price': 'Â£43.14', 'availability': 'In stock'}
# {'title': 'Psycho: Sanitarium (Psycho #1.5)', 'price': 'Â£36.97', 'availability': 'In stock'}
# {'title': 'Poisonous (Max Revere Novels #3)', 'price': 'Â£26.80', 'availability': 'In stock'}
# {'title': 'One with You (Crossfire #5)', 'price': 'Â£15.71', 'availability': 'In stock'}
# {'title': 'No Love Allowed (Dodge Cove #1)', 'price': 'Â£54.65', 'availability': 'In stock'}
# {'title': 'Murder at the 42nd Street Library (Raymond Ambler #1)', 'price': 'Â£54.36', 'availability': 'In stock'}
# {'title': 'Most Wanted', 'price': 'Â£35.28', 'availability': 'In stock'}
# {'title': 'Love, Lies and Spies', 'price': 'Â£20.55', 'availability': 'In stock'}
# {'title': 'How to Speak Golf: An Illustrated Guide to Links Lingo', 'price': 'Â£58.32', 'availability': 'In stock'}
# {'title': 'Hide Away (Eve Duncan #20)', 'price': 'Â£11.84', 'availability': 'In stock'}
# {'title': 'Furiously Happy: A Funny Book About Horrible Things', 'price': 'Â£41.46', 'availability': 'In stock'}
# {'title': 'Everyday Italian: 125 Simple and Delicious Recipes', 'price': 'Â£20.10', 'availability': 'In stock'}
# {'title': "Equal Is Unfair: America's Misguided Fight Against Income Inequality", 'price': 'Â£56.86', 'availability': 'In stock'}
# {'title': 'Eleanor & Park', 'price': 'Â£56.51', 'availability': 'In stock'}
# {'title': 'Dirty (Dive Bar #1)', 'price': 'Â£40.83', 'availability': 'In stock'}
# {'title': 'Can You Keep a Secret? (Fear Street Relaunch #4)', 'price': 'Â£48.64', 'availability': 'In stock'}
# {'title': 'Boar Island (Anna Pigeon #19)', 'price': 'Â£59.48', 'availability': 'In stock'}
# {'title': 'A Paris Apartment', 'price': 'Â£39.01', 'availability': 'In stock'}
# {'title': 'A la Mode: 120 Recipes in 60 Pairings: Pies, Tarts, Cakes, Crisps, and More Topped with Ice Cream, Gelato, Frozen Custard, and More', 'price': 'Â£38.77', 'availability': 'In stock'}
# {'title': 'Troublemaker: Surviving Hollywood and Scientology', 'price': 'Â£48.39', 'availability': 'In stock'}
# {'title': 'The Widow', 'price': 'Â£27.26', 'availability': 'In stock'}
# {'title': 'The Sleep Revolution: Transforming Your Life, One Night at a Time', 'price': 'Â£11.68', 'availability': 'In stock'}
# {'title': 'The Improbability of Love', 'price': 'Â£59.45', 'availability': 'In stock'}
# {'title': 'The Art of Startup Fundraising', 'price': 'Â£21.00', 'availability': 'In stock'}
# {'title': 'Take Me Home Tonight (Rock Star Romance #3)', 'price': 'Â£53.98', 'availability': 'In stock'}
# {'title': 'Sleeping Giants (Themis Files #1)', 'price': 'Â£48.74', 'availability': 'In stock'}
# {'title': 'Setting the World on Fire: The Brief, Astonishing Life of St. Catherine of Siena', 'price': 'Â£21.15', 'availability': 'In stock'}
# {'title': 'Playing with Fire', 'price': 'Â£13.71', 'availability': 'In stock'}
# {'title': 'Off the Hook (Fishing for Trouble #1)', 'price': 'Â£47.67', 'availability': 'In stock'}
# {'title': 'Mothering Sunday', 'price': 'Â£13.34', 'availability': 'In stock'}
# {'title': 'Mother, Can You Not?', 'price': 'Â£16.89', 'availability': 'In stock'}
# {'title': 'M Train', 'price': 'Â£27.18', 'availability': 'In stock'}
# {'title': 'Lilac Girls', 'price': 'Â£17.28', 'availability': 'In stock'}
# {'title': 'Lies and Other Acts of Love', 'price': 'Â£45.14', 'availability': 'In stock'}
# {'title': 'Lab Girl', 'price': 'Â£40.85', 'availability': 'In stock'}
# {'title': 'Keep Me Posted', 'price': 'Â£20.46', 'availability': 'In stock'}
# {'title': "It Didn't Start with You: How Inherited Family Trauma Shapes Who We Are and How to End the Cycle", 'price': 'Â£56.27', 'availability': 'In stock'}
# {'title': 'Grey (Fifty Shades #4)', 'price': 'Â£48.49', 'availability': 'In stock'}
# {'title': 'Exit, Pursued by a Bear', 'price': 'Â£51.34', 'availability': 'In stock'}
# {'title': 'Daredevils', 'price': 'Â£16.34', 'availability': 'In stock'}
# {'title': 'Cravings: Recipes for What You Want to Eat', 'price': 'Â£20.50', 'availability': 'In stock'}
# {'title': 'Born for This: How to Find the Work You Were Meant to Do', 'price': 'Â£21.59', 'availability': 'In stock'}
# {'title': 'Arena', 'price': 'Â£21.36', 'availability': 'In stock'}
# {'title': 'Adultery', 'price': 'Â£20.88', 'availability': 'In stock'}
# {'title': "A Mother's Reckoning: Living in the Aftermath of Tragedy", 'price': 'Â£19.53', 'availability': 'In stock'}
# {'title': "A Gentleman's Position (Society of Gentlemen #3)", 'price': 'Â£14.75', 'availability': 'In stock'}
# {'title': '11/22/63', 'price': 'Â£48.48', 'availability': 'In stock'}
# {'title': '10% Happier: How I Tamed the Voice in My Head, Reduced Stress Without Losing My Edge, and Found Self-Help That Actually Works', 'price': 'Â£24.57', 'availability': 'In stock'}
# {'title': '10-Day Green Smoothie Cleanse: Lose Up to 15 Pounds in 10 Days!', 'price': 'Â£49.71', 'availability': 'In stock'}
# {'title': 'Without Shame', 'price': 'Â£48.27', 'availability': 'In stock'}
# {'title': 'Watchmen', 'price': 'Â£58.05', 'availability': 'In stock'}
# {'title': 'Unlimited Intuition Now', 'price': 'Â£58.87', 'availability': 'In stock'}
# {'title': 'Underlying Notes', 'price': 'Â£11.82', 'availability': 'In stock'}
# {'title': 'The Shack', 'price': 'Â£28.03', 'availability': 'In stock'}
# {'title': 'The New Brand You: Your New Image Makes the Sale for You', 'price': 'Â£44.05', 'availability': 'In stock'}
# {'title': 'The Moosewood Cookbook: Recipes from Moosewood Restaurant, Ithaca, New York', 'price': 'Â£12.34', 'availability': 'In stock'}
# {'title': 'The Flowers Lied', 'price': 'Â£16.68', 'availability': 'In stock'}
# {'title': 'The Fabric of the Cosmos: Space, Time, and the Texture of Reality', 'price': 'Â£55.91', 'availability': 'In stock'}
# {'title': 'The Book of Mormon', 'price': 'Â£24.57', 'availability': 'In stock'}
# {'title': 'The Art and Science of Low Carbohydrate Living', 'price': 'Â£52.98', 'availability': 'In stock'}
# {'title': 'The Alien Club', 'price': 'Â£54.40', 'availability': 'In stock'}
# {'title': 'Suzie Snowflake: One beautiful flake (a self-esteem story)', 'price': 'Â£54.81', 'availability': 'In stock'}
# {'title': 'Nap-a-Roo', 'price': 'Â£25.08', 'availability': 'In stock'}
# {'title': 'NaNo What Now? Finding your editing process, revising your NaNoWriMo book and building a writing career through publishing and beyond', 'price': 'Â£10.41', 'availability': 'In stock'}
# {'title': 'Modern Day Fables', 'price': 'Â£47.44', 'availability': 'In stock'}
# {'title': "If I Gave You God's Phone Number....: Searching for Spirituality in America", 'price': 'Â£20.91', 'availability': 'In stock'}
# {'title': 'Fruits Basket, Vol. 9 (Fruits Basket #9)', 'price': 'Â£33.95', 'availability': 'In stock'}
# {'title': 'Dress Your Family in Corduroy and Denim', 'price': 'Â£43.68', 'availability': 'In stock'}
# {'title': "Don't Forget Steven", 'price': 'Â£33.23', 'availability': 'In stock'}
# {'title': "Chernobyl 01:23:40: The Incredible True Story of the World's Worst Nuclear Disaster", 'price': 'Â£35.92', 'availability': 'In stock'}
# {'title': 'Art and Fear: Observations on the Perils (and Rewards) of Artmaking', 'price': 'Â£48.63', 'availability': 'In stock'}
# {'title': 'A Shard of Ice (The Black Symphony Saga #1)', 'price': 'Â£56.63', 'availability': 'In stock'}
# {'title': "A Hero's Curse (The Unseen Chronicles #1)", 'price': 'Â£50.49', 'availability': 'In stock'}
# {'title': '23 Degrees South: A Tropical Tale of Changing Whether...', 'price': 'Â£35.79', 'availability': 'In stock'}
# {'title': 'Zero to One: Notes on Startups, or How to Build the Future', 'price': 'Â£34.06', 'availability': 'In stock'}
# {'title': 'Why Not Me?', 'price': 'Â£17.76', 'availability': 'In stock'}
# {'title': 'When Breath Becomes Air', 'price': 'Â£39.36', 'availability': 'In stock'}
# {'title': 'Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel', 'price': 'Â£36.94', 'availability': 'In stock'}
# {'title': 'The Unlikely Pilgrimage of Harold Fry (Harold Fry #1)', 'price': 'Â£43.62', 'availability': 'In stock'}
# {'title': 'The New Drawing on the Right Side of the Brain', 'price': 'Â£43.02', 'availability': 'In stock'}
# {'title': "The Midnight Assassin: Panic, Scandal, and the Hunt for America's First Serial Killer", 'price': 'Â£28.45', 'availability': 'In stock'}
# {'title': 'The Martian (The Martian #1)', 'price': 'Â£41.39', 'availability': 'In stock'}
# {'title': 'The High Mountains of Portugal', 'price': 'Â£51.15', 'availability': 'In stock'}
# {'title': 'The Grownup', 'price': 'Â£35.88', 'availability': 'In stock'}
# {'title': "The E-Myth Revisited: Why Most Small Businesses Don't Work and What to Do About It", 'price': 'Â£36.91', 'availability': 'In stock'}
# {'title': 'South of Sunshine', 'price': 'Â£28.93', 'availability': 'In stock'}
# {'title': 'Smarter Faster Better: The Secrets of Being Productive in Life and Business', 'price': 'Â£38.89', 'availability': 'In stock'}
# {'title': 'Silence in the Dark (Logan Point #4)', 'price': 'Â£58.33', 'availability': 'In stock'}
# {'title': 'Shadows of the Past (Logan Point #1)', 'price': 'Â£39.67', 'availability': 'In stock'}
# {'title': 'Roller Girl', 'price': 'Â£14.10', 'availability': 'In stock'}
# {'title': 'Rising Strong', 'price': 'Â£21.82', 'availability': 'In stock'}
# ...
# {'title': 'House of Lost Worlds: Dinosaurs, Dynasties, and the Story of Life on Earth', 'price': 'Â£43.70', 'availability': 'In stock'}
# {'title': 'House of Leaves', 'price': 'Â£54.89', 'availability': 'In stock'}
# {'title': 'Horrible Bear!', 'price': 'Â£37.52', 'availability': 'In stock'}
# {'title': 'Holidays on Ice', 'price': 'Â£51.07', 'availability': 'In stock'}
# {'title': 'Heir to the Sky', 'price': 'Â£44.07', 'availability': 'In stock'}
# {'title': 'Green Eggs and Ham (Beginner Books B-16)', 'price': 'Â£10.79', 'availability': 'In stock'}
# {'title': 'Grayson, Vol 3: Nemesis (Grayson #3)', 'price': 'Â£42.72', 'availability': 'In stock'}
# {'title': 'Gratitude', 'price': 'Â£26.66', 'availability': 'In stock'}
# {'title': 'Gone Girl', 'price': 'Â£37.60', 'availability': 'In stock'}
# {'title': 'Golden (Heart of Dread #3)', 'price': 'Â£42.21', 'availability': 'In stock'}
# {'title': 'Girl in the Blue Coat', 'price': 'Â£46.83', 'availability': 'In stock'}
# {'title': 'Fruits Basket, Vol. 3 (Fruits Basket #3)', 'price': 'Â£45.17', 'availability': 'In stock'}
# {'title': 'Friday Night Lights: A Town, a Team, and a Dream', 'price': 'Â£51.22', 'availability': 'In stock'}
# {'title': 'Fire Bound (Sea Haven/Sisters of the Heart #5)', 'price': 'Â£21.28', 'availability': 'In stock'}
# {'title': 'Fifty Shades Freed (Fifty Shades #3)', 'price': 'Â£15.36', 'availability': 'In stock'}
# {'title': 'Fellside', 'price': 'Â£38.62', 'availability': 'In stock'}
# {'title': 'Extreme Prey (Lucas Davenport #26)', 'price': 'Â£25.40', 'availability': 'In stock'}
# {'title': 'Eragon (The Inheritance Cycle #1)', 'price': 'Â£43.87', 'availability': 'In stock'}
# {'title': 'Eclipse (Twilight #3)', 'price': 'Â£18.74', 'availability': 'In stock'}
# {'title': 'Dune (Dune #1)', 'price': 'Â£54.86', 'availability': 'In stock'}
# {'title': 'Dracula', 'price': 'Â£52.62', 'availability': 'In stock'}
# {'title': 'Do Androids Dream of Electric Sheep? (Blade Runner #1)', 'price': 'Â£51.48', 'availability': 'In stock'}
# {'title': 'Disrupted: My Misadventure in the Start-Up Bubble', 'price': 'Â£15.28', 'availability': 'In stock'}
# {'title': 'Dead Wake: The Last Crossing of the Lusitania', 'price': 'Â£39.24', 'availability': 'In stock'}
# {'title': 'David and Goliath: Underdogs, Misfits, and the Art of Battling Giants', 'price': 'Â£17.81', 'availability': 'In stock'}
# {'title': 'Darkfever (Fever #1)', 'price': 'Â£56.02', 'availability': 'In stock'}
# {'title': 'Dark Places', 'price': 'Â£23.90', 'availability': 'In stock'}
# {'title': 'Crazy Rich Asians (Crazy Rich Asians #1)', 'price': 'Â£49.13', 'availability': 'In stock'}
# {'title': 'Counting Thyme', 'price': 'Â£10.62', 'availability': 'In stock'}
# {'title': 'Cosmos', 'price': 'Â£36.17', 'availability': 'In stock'}
# {'title': 'Civilization and Its Discontents', 'price': 'Â£59.95', 'availability': 'In stock'}
# {'title': 'Cinder (The Lunar Chronicles #1)', 'price': 'Â£26.09', 'availability': 'In stock'}
# {'title': "Catastrophic Happiness: Finding Joy in Childhood's Messy Years", 'price': 'Â£37.35', 'availability': 'In stock'}
# {'title': 'Career of Evil (Cormoran Strike #3)', 'price': 'Â£24.72', 'availability': 'In stock'}
# {'title': 'Breaking Dawn (Twilight #4)', 'price': 'Â£35.28', 'availability': 'In stock'}
# {'title': 'Brave Enough', 'price': 'Â£51.32', 'availability': 'In stock'}
# {'title': 'Boy Meets Boy', 'price': 'Â£21.12', 'availability': 'In stock'}
# {'title': 'Born to Run: A Hidden Tribe, Superathletes, and the Greatest Race the World Has Never Seen', 'price': 'Â£27.35', 'availability': 'In stock'}
# {'title': 'Blink: The Power of Thinking Without Thinking', 'price': 'Â£21.74', 'availability': 'In stock'}
# {'title': 'Black Flags: The Rise of ISIS', 'price': 'Â£40.87', 'availability': 'In stock'}
# {'title': 'Black Butler, Vol. 1 (Black Butler #1)', 'price': 'Â£49.31', 'availability': 'In stock'}
# {'title': 'Big Little Lies', 'price': 'Â£22.11', 'availability': 'In stock'}
# {'title': 'Between Shades of Gray', 'price': 'Â£20.79', 'availability': 'In stock'}
# {'title': "Best of My Love (Fool's Gold #20)", 'price': 'Â£27.41', 'availability': 'In stock'}
# {'title': 'Beowulf', 'price': 'Â£38.35', 'availability': 'In stock'}
# {'title': 'Beautiful Creatures (Caster Chronicles #1)', 'price': 'Â£21.55', 'availability': 'In stock'}
# {'title': 'Awkward', 'price': 'Â£38.02', 'availability': 'In stock'}
# {'title': 'Ash', 'price': 'Â£22.06', 'availability': 'In stock'}
# {'title': 'Are We There Yet?', 'price': 'Â£10.66', 'availability': 'In stock'}
# {'title': 'Are We Smart Enough to Know How Smart Animals Are?', 'price': 'Â£56.58', 'availability': 'In stock'}
# {'title': 'Annie on My Mind', 'price': 'Â£36.83', 'availability': 'In stock'}
# {'title': 'And Then There Were None', 'price': 'Â£35.01', 'availability': 'In stock'}
# {'title': 'A Walk in the Woods: Rediscovering America on the Appalachian Trail', 'price': 'Â£30.48', 'availability': 'In stock'}
# {'title': 'A Visit from the Goon Squad', 'price': 'Â£14.08', 'availability': 'In stock'}
# {'title': 'A Storm of Swords (A Song of Ice and Fire #3)', 'price': 'Â£31.22', 'availability': 'In stock'}
# {'title': 'A Heartbreaking Work of Staggering Genius', 'price': 'Â£54.29', 'availability': 'In stock'}
# {'title': '8 Keys to Mental Health Through Exercise', 'price': 'Â£31.04', 'availability': 'In stock'}
# {'title': '#GIRLBOSS', 'price': 'Â£50.96', 'availability': 'In stock'}
# {'title': 'The Suffragettes (Little Black Classics, #96)', 'price': 'Â£11.89', 'availability': 'In stock'}
# {'title': 'The Sense of an Ending', 'price': 'Â£31.38', 'availability': 'In stock'}
# {'title': "The Sandman, Vol. 2: The Doll's House (The Sandman (volumes) #2)", 'price': 'Â£54.81', 'availability': 'In stock'}
# {'title': 'The Course of Love', 'price': 'Â£16.78', 'availability': 'In stock'}
# {'title': 'Sugar Rush (Offensive Line #2)', 'price': 'Â£24.42', 'availability': 'In stock'}
# {'title': 'Saga, Volume 2 (Saga (Collected Editions) #2)', 'price': 'Â£11.75', 'availability': 'In stock'}
# {'title': 'Run, Spot, Run: The Ethics of Keeping Pets', 'price': 'Â£20.02', 'availability': 'In stock'}
# {'title': 'New Moon (Twilight #2)', 'price': 'Â£12.86', 'availability': 'In stock'}
# {'title': 'Life', 'price': 'Â£31.58', 'availability': 'In stock'}
# {'title': "Kindle Paperwhite User's Guide", 'price': 'Â£34.00', 'availability': 'In stock'}
# {'title': 'H is for Hawk', 'price': 'Â£57.42', 'availability': 'In stock'}
# {'title': 'Girl Online On Tour (Girl Online #2)', 'price': 'Â£53.47', 'availability': 'In stock'}
# {'title': 'Fruits Basket, Vol. 2 (Fruits Basket #2)', 'price': 'Â£11.64', 'availability': 'In stock'}
# {'title': 'Diary of a Minecraft Zombie Book 1: A Scare of a Dare (An Unofficial Minecraft Book)', 'price': 'Â£52.88', 'availability': 'In stock'}
# {'title': 'Y: The Last Man, Vol. 1: Unmanned (Y: The Last Man #1)', 'price': 'Â£18.51', 'availability': 'In stock'}
# {'title': 'While You Were Mine', 'price': 'Â£41.32', 'availability': 'In stock'}
# {'title': 'Where Lightning Strikes (Bleeding Stars #3)', 'price': 'Â£39.77', 'availability': 'In stock'}
# {'title': "When I'm Gone", 'price': 'Â£51.96', 'availability': 'In stock'}
# {'title': 'Ways of Seeing', 'price': 'Â£39.51', 'availability': 'In stock'}
# {'title': 'Vampire Knight, Vol. 1 (Vampire Knight #1)', 'price': 'Â£15.40', 'availability': 'In stock'}
# {'title': 'Vampire Girl (Vampire Girl #1)', 'price': 'Â£53.82', 'availability': 'In stock'}
# {'title': 'Twenty Love Poems and a Song of Despair', 'price': 'Â£30.95', 'availability': 'In stock'}
# {'title': 'Travels with Charley: In Search of America', 'price': 'Â£57.82', 'availability': 'In stock'}
# {'title': 'Three Wishes (River of Time: California #1)', 'price': 'Â£44.18', 'availability': 'In stock'}
# {'title': 'This One Moment (Pushing Limits #1)', 'price': 'Â£48.71', 'availability': 'In stock'}
# {'title': 'The Zombie Room', 'price': 'Â£19.69', 'availability': 'In stock'}
# {'title': 'The Wicked + The Divine, Vol. 1: The Faust Act (The Wicked + The Divine)', 'price': 'Â£36.52', 'availability': 'In stock'}
# {'title': 'The Tumor', 'price': 'Â£41.56', 'availability': 'In stock'}
# {'title': 'The Story of Hong Gildong', 'price': 'Â£43.19', 'availability': 'In stock'}
# {'title': 'The Silent Wife', 'price': 'Â£12.34', 'availability': 'In stock'}
# {'title': 'The Silent Twin (Detective Jennifer Knight #3)', 'price': 'Â£36.25', 'availability': 'In stock'}
# {'title': 'The Selfish Gene', 'price': 'Â£29.45', 'availability': 'In stock'}
# {'title': 'The Secret Healer', 'price': 'Â£34.56', 'availability': 'In stock'}
# {'title': 'The Sandman, Vol. 1: Preludes and Nocturnes (The Sandman (volumes) #1)', 'price': 'Â£54.12', 'availability': 'In stock'}
# {'title': 'The Republic', 'price': 'Â£33.78', 'availability': 'In stock'}
# {'title': 'The Odyssey', 'price': 'Â£29.64', 'availability': 'In stock'}
# {'title': "The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency #1)", 'price': 'Â£57.70', 'availability': 'In stock'}
# {'title': 'The Nicomachean Ethics', 'price': 'Â£36.34', 'availability': 'In stock'}
# {'title': 'The Name of the Wind (The Kingkiller Chronicle #1)', 'price': 'Â£50.59', 'availability': 'In stock'}
# {'title': 'The Mirror & the Maze (The Wrath and the Dawn #1.5)', 'price': 'Â£29.38', 'availability': 'In stock'}
# {'title': 'The Little Prince', 'price': 'Â£45.42', 'availability': 'In stock'}
# {'title': 'The Light of the Fireflies', 'price': 'Â£54.43', 'availability': 'In stock'}
# {'title': 'The Last Girl (The Dominion Trilogy #1)', 'price': 'Â£36.26', 'availability': 'In stock'}
# {'title': 'The Iliad', 'price': 'Â£16.16', 'availability': 'In stock'}
# {'title': 'The Hook Up (Game On #1)', 'price': 'Â£36.29', 'availability': 'In stock'}
# {'title': 'The Haters', 'price': 'Â£27.89', 'availability': 'In stock'}
# {'title': 'The Girl You Lost', 'price': 'Â£12.29', 'availability': 'In stock'}
# {'title': 'The Girl In The Ice (DCI Erika Foster #1)', 'price': 'Â£15.85', 'availability': 'In stock'}
# {'title': 'The End of the Jesus Era (An Investigation #1)', 'price': 'Â£14.40', 'availability': 'In stock'}
# {'title': 'The Edge of Reason (Bridget Jones #2)', 'price': 'Â£19.18', 'availability': 'In stock'}
# {'title': 'The Complete Maus (Maus #1-2)', 'price': 'Â£10.64', 'availability': 'In stock'}
# {'title': 'The Communist Manifesto', 'price': 'Â£14.76', 'availability': 'In stock'}
# {'title': 'The Bhagavad Gita', 'price': 'Â£57.49', 'availability': 'In stock'}
# {'title': 'The Bette Davis Club', 'price': 'Â£30.66', 'availability': 'In stock'}
# {'title': 'The Art of Not Breathing', 'price': 'Â£40.83', 'availability': 'In stock'}
# {'title': 'Taking Shots (Assassins #1)', 'price': 'Â£18.88', 'availability': 'In stock'}
# {'title': 'Starlark', 'price': 'Â£25.83', 'availability': 'In stock'}
# {'title': 'Skip Beat!, Vol. 01 (Skip Beat! #1)', 'price': 'Â£42.12', 'availability': 'In stock'}
# {'title': 'Sister Sable (The Mad Queen #1)', 'price': 'Â£13.33', 'availability': 'In stock'}
# {'title': 'Shatter Me (Shatter Me #1)', 'price': 'Â£42.40', 'availability': 'In stock'}
# {'title': 'Shameless', 'price': 'Â£58.35', 'availability': 'In stock'}
# {'title': 'Shadow Rites (Jane Yellowrock #10)', 'price': 'Â£21.72', 'availability': 'In stock'}
# {'title': 'Settling the Score (The Summer Games #1)', 'price': 'Â£44.91', 'availability': 'In stock'}
# {'title': 'Sense and Sensibility', 'price': 'Â£37.46', 'availability': 'In stock'}
# {'title': 'Saga, Volume 1 (Saga (Collected Editions) #1)', 'price': 'Â£28.48', 'availability': 'In stock'}
# {'title': 'Rhythm, Chord & Malykhin', 'price': 'Â£28.34', 'availability': 'In stock'}
# {'title': 'Rat Queens, Vol. 1: Sass & Sorcery (Rat Queens (Collected Editions) #1-5)', 'price': 'Â£46.96', 'availability': 'In stock'}
# {'title': 'Paradise Lost (Paradise #1)', 'price': 'Â£24.96', 'availability': 'In stock'}
# {'title': 'Paper Girls, Vol. 1 (Paper Girls #1-5)', 'price': 'Â£21.71', 'availability': 'In stock'}
# {'title': 'Ouran High School Host Club, Vol. 1 (Ouran High School Host Club #1)', 'price': 'Â£29.87', 'availability': 'In stock'}
# {'title': 'Origins (Alphas 0.5)', 'price': 'Â£28.99', 'availability': 'In stock'}
# {'title': 'One Second (Seven #7)', 'price': 'Â£52.94', 'availability': 'In stock'}
# {'title': 'On the Road (Duluoz Legend)', 'price': 'Â£32.36', 'availability': 'In stock'}
# {'title': "Old Records Never Die: One Man's Quest for His Vinyl and His Past", 'price': 'Â£55.66', 'availability': 'In stock'}
# {'title': 'Off Sides (Off #1)', 'price': 'Â£39.45', 'availability': 'In stock'}
# {'title': 'Of Mice and Men', 'price': 'Â£47.11', 'availability': 'In stock'}
# {'title': 'Myriad (Prentor #1)', 'price': 'Â£58.75', 'availability': 'In stock'}
# {'title': 'My Perfect Mistake (Over the Top #1)', 'price': 'Â£38.92', 'availability': 'In stock'}
# {'title': 'Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1)', 'price': 'Â£39.39', 'availability': 'In stock'}
# {'title': 'Meditations', 'price': 'Â£25.89', 'availability': 'In stock'}
# {'title': 'Matilda', 'price': 'Â£28.34', 'availability': 'In stock'}
# {'title': 'Lost Among the Living', 'price': 'Â£27.70', 'availability': 'In stock'}
# {'title': 'Lord of the Flies', 'price': 'Â£24.89', 'availability': 'In stock'}
# {'title': 'Listen to Me (Fusion #1)', 'price': 'Â£58.99', 'availability': 'In stock'}
# {'title': 'Kitchens of the Great Midwest', 'price': 'Â£57.20', 'availability': 'In stock'}
# {'title': 'Jane Eyre', 'price': 'Â£38.43', 'availability': 'In stock'}
# {'title': 'Imperfect Harmony', 'price': 'Â£34.74', 'availability': 'In stock'}
# {'title': 'Icing (Aces Hockey #2)', 'price': 'Â£40.44', 'availability': 'In stock'}
# {'title': 'Hawkeye, Vol. 1: My Life as a Weapon (Hawkeye #1)', 'price': 'Â£45.24', 'availability': 'In stock'}
# {'title': "Having the Barbarian's Baby (Ice Planet Barbarians #7.5)", 'price': 'Â£34.96', 'availability': 'In stock'}
# {'title': 'Giant Days, Vol. 1 (Giant Days #1-4)', 'price': 'Â£56.76', 'availability': 'In stock'}
# {'title': 'Fruits Basket, Vol. 1 (Fruits Basket #1)', 'price': 'Â£40.28', 'availability': 'In stock'}
# {'title': 'Frankenstein', 'price': 'Â£38.00', 'availability': 'In stock'}
# {'title': 'Forever Rockers (The Rocker #12)', 'price': 'Â£28.80', 'availability': 'In stock'}
# {'title': 'Fighting Fate (Fighting #6)', 'price': 'Â£39.24', 'availability': 'In stock'}
# {'title': 'Emma', 'price': 'Â£32.93', 'availability': 'In stock'}
# {'title': 'Eat, Pray, Love', 'price': 'Â£51.32', 'availability': 'In stock'}
# {'title': 'Deep Under (Walker Security #1)', 'price': 'Â£47.09', 'availability': 'In stock'}
# {'title': "Choosing Our Religion: The Spiritual Lives of America's Nones", 'price': 'Â£28.42', 'availability': 'In stock'}
# {'title': 'Charlie and the Chocolate Factory (Charlie Bucket #1)', 'price': 'Â£22.85', 'availability': 'In stock'}
# {'title': "Charity's Cross (Charles Towne Belles #4)", 'price': 'Â£41.24', 'availability': 'In stock'}
# {'title': 'Bright Lines', 'price': 'Â£39.07', 'availability': 'In stock'}
# {'title': "Bridget Jones's Diary (Bridget Jones #1)", 'price': 'Â£29.82', 'availability': 'In stock'}
# {'title': 'Bounty (Colorado Mountain #7)', 'price': 'Â£37.26', 'availability': 'In stock'}
# {'title': 'Blood Defense (Samantha Brinkman #1)', 'price': 'Â£20.30', 'availability': 'In stock'}
# {'title': 'Bleach, Vol. 1: Strawberry and the Soul Reapers (Bleach #1)', 'price': 'Â£34.65', 'availability': 'In stock'}
# {'title': 'Beyond Good and Evil', 'price': 'Â£43.38', 'availability': 'In stock'}
# {'title': "Alice in Wonderland (Alice's Adventures in Wonderland #1)", 'price': 'Â£55.53', 'availability': 'In stock'}
# {'title': 'Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)', 'price': 'Â£57.06', 'availability': 'In stock'}
# {'title': "A Spy's Devotion (The Regency Spies of London #1)", 'price': 'Â£16.97', 'availability': 'In stock'}
# {'title': "1st to Die (Women's Murder Club #1)", 'price': 'Â£53.98', 'availability': 'In stock'}
# {'title': '1,000 Places to See Before You Die', 'price': 'Â£26.08', 'availability': 'In stock'}

# %%
#Add lazy loading: ensure scrape_all() does not store any full page or full item list in memory.
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# Generator to fetch pages lazily
def fetch_page(url):

    while url:
        response = requests.get(url)
        html = response.text
        yield html

        # Find next page
        soup = BeautifulSoup(html, "html.parser")
        next_button = soup.find("li", class_="next")
        if next_button and next_button.a:
            next_href = next_button.a.get("href")
            url = urljoin(start_url, next_href)
        else:
            url = None

# Generator to parse items from a single page
def parse_items(html):
    soup = BeautifulSoup(html, "html.parser")
    books = soup.find_all("article", class_="product_pod")
    for book in books:
        title = book.h3.a["title"]
        price = book.find("p", class_="price_color").text
        availability = book.find("p", class_="instock availability").text.strip()
        yield {
            "title": title,
            "price": price,
            "availability": availability
        }

# Generator to scrape all items across all pages lazily
def scrape_all(start_url):
    for page_html in fetch_page(start_url):          # fetch one page at a time
        for item in parse_items(page_html):         # parse items lazily from that page
            yield item                              # yield one item at a time

# Usage example
start_url = "http://books.toscrape.com/catalogue/page-1.html"
for book in scrape_all(start_url):
    print(book)
# Out:
# {'title': 'A Light in the Attic', 'price': 'Â£51.77', 'availability': 'In stock'}
# {'title': 'Tipping the Velvet', 'price': 'Â£53.74', 'availability': 'In stock'}
# {'title': 'Soumission', 'price': 'Â£50.10', 'availability': 'In stock'}
# {'title': 'Sharp Objects', 'price': 'Â£47.82', 'availability': 'In stock'}
# {'title': 'Sapiens: A Brief History of Humankind', 'price': 'Â£54.23', 'availability': 'In stock'}
# {'title': 'The Requiem Red', 'price': 'Â£22.65', 'availability': 'In stock'}
# {'title': 'The Dirty Little Secrets of Getting Your Dream Job', 'price': 'Â£33.34', 'availability': 'In stock'}
# {'title': 'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull', 'price': 'Â£17.93', 'availability': 'In stock'}
# {'title': 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics', 'price': 'Â£22.60', 'availability': 'In stock'}
# {'title': 'The Black Maria', 'price': 'Â£52.15', 'availability': 'In stock'}
# {'title': 'Starving Hearts (Triangular Trade Trilogy, #1)', 'price': 'Â£13.99', 'availability': 'In stock'}
# {'title': "Shakespeare's Sonnets", 'price': 'Â£20.66', 'availability': 'In stock'}
# {'title': 'Set Me Free', 'price': 'Â£17.46', 'availability': 'In stock'}
# {'title': "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)", 'price': 'Â£52.29', 'availability': 'In stock'}
# {'title': 'Rip it Up and Start Again', 'price': 'Â£35.02', 'availability': 'In stock'}
# {'title': 'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991', 'price': 'Â£57.25', 'availability': 'In stock'}
# {'title': 'Olio', 'price': 'Â£23.88', 'availability': 'In stock'}
# {'title': 'Mesaerion: The Best Science Fiction Stories 1800-1849', 'price': 'Â£37.59', 'availability': 'In stock'}
# {'title': 'Libertarianism for Beginners', 'price': 'Â£51.33', 'availability': 'In stock'}
# {'title': "It's Only the Himalayas", 'price': 'Â£45.17', 'availability': 'In stock'}
# {'title': 'In Her Wake', 'price': 'Â£12.84', 'availability': 'In stock'}
# {'title': 'How Music Works', 'price': 'Â£37.32', 'availability': 'In stock'}
# {'title': 'Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More', 'price': 'Â£30.52', 'availability': 'In stock'}
# {'title': 'Chase Me (Paris Nights #2)', 'price': 'Â£25.27', 'availability': 'In stock'}
# {'title': 'Black Dust', 'price': 'Â£34.53', 'availability': 'In stock'}
# {'title': 'Birdsong: A Story in Pictures', 'price': 'Â£54.64', 'availability': 'In stock'}
# {'title': "America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana", 'price': 'Â£22.50', 'availability': 'In stock'}
# {'title': 'Aladdin and His Wonderful Lamp', 'price': 'Â£53.13', 'availability': 'In stock'}
# {'title': 'Worlds Elsewhere: Journeys Around Shakespeareâ\x80\x99s Globe', 'price': 'Â£40.30', 'availability': 'In stock'}
# {'title': 'Wall and Piece', 'price': 'Â£44.18', 'availability': 'In stock'}
# {'title': 'The Four Agreements: A Practical Guide to Personal Freedom', 'price': 'Â£17.66', 'availability': 'In stock'}
# {'title': 'The Five Love Languages: How to Express Heartfelt Commitment to Your Mate', 'price': 'Â£31.05', 'availability': 'In stock'}
# {'title': 'The Elephant Tree', 'price': 'Â£23.82', 'availability': 'In stock'}
# {'title': 'The Bear and the Piano', 'price': 'Â£36.89', 'availability': 'In stock'}
# {'title': "Sophie's World", 'price': 'Â£15.94', 'availability': 'In stock'}
# {'title': 'Penny Maybe', 'price': 'Â£33.29', 'availability': 'In stock'}
# {'title': 'Maude (1883-1993):She Grew Up with the country', 'price': 'Â£18.02', 'availability': 'In stock'}
# {'title': 'In a Dark, Dark Wood', 'price': 'Â£19.63', 'availability': 'In stock'}
# {'title': 'Behind Closed Doors', 'price': 'Â£52.22', 'availability': 'In stock'}
# {'title': "You can't bury them all: Poems", 'price': 'Â£33.63', 'availability': 'In stock'}
# {'title': 'Slow States of Collapse: Poems', 'price': 'Â£57.31', 'availability': 'In stock'}
# {'title': 'Reasons to Stay Alive', 'price': 'Â£26.41', 'availability': 'In stock'}
# {'title': 'Private Paris (Private #10)', 'price': 'Â£47.61', 'availability': 'In stock'}
# {'title': '#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.', 'price': 'Â£23.11', 'availability': 'In stock'}
# {'title': 'Without Borders (Wanderlove #1)', 'price': 'Â£45.07', 'availability': 'In stock'}
# {'title': 'When We Collided', 'price': 'Â£31.77', 'availability': 'In stock'}
# {'title': 'We Love You, Charlie Freeman', 'price': 'Â£50.27', 'availability': 'In stock'}
# {'title': 'Untitled Collection: Sabbath Poems 2014', 'price': 'Â£14.27', 'availability': 'In stock'}
# {'title': 'Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails & Other Wonders of the Urban Wilderness', 'price': 'Â£44.18', 'availability': 'In stock'}
# {'title': 'Unicorn Tracks', 'price': 'Â£18.78', 'availability': 'In stock'}
# {'title': 'Unbound: How Eight Technologies Made Us Human, Transformed Society, and Brought Our World to the Brink', 'price': 'Â£25.52', 'availability': 'In stock'}
# {'title': 'Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2)', 'price': 'Â£16.28', 'availability': 'In stock'}
# {'title': 'Throwing Rocks at the Google Bus: How Growth Became the Enemy of Prosperity', 'price': 'Â£31.12', 'availability': 'In stock'}
# {'title': 'This One Summer', 'price': 'Â£19.49', 'availability': 'In stock'}
# {'title': 'Thirst', 'price': 'Â£17.27', 'availability': 'In stock'}
# {'title': 'The Torch Is Passed: A Harding Family Story', 'price': 'Â£19.09', 'availability': 'In stock'}
# {'title': 'The Secret of Dreadwillow Carse', 'price': 'Â£56.13', 'availability': 'In stock'}
# {'title': 'The Pioneer Woman Cooks: Dinnertime: Comfort Classics, Freezer Food, 16-Minute Meals, and Other Delicious Ways to Solve Supper!', 'price': 'Â£56.41', 'availability': 'In stock'}
# {'title': 'The Past Never Ends', 'price': 'Â£56.50', 'availability': 'In stock'}
# {'title': 'The Natural History of Us (The Fine Art of Pretending #2)', 'price': 'Â£45.22', 'availability': 'In stock'}
# {'title': 'The Nameless City (The Nameless City #1)', 'price': 'Â£38.16', 'availability': 'In stock'}
# {'title': 'The Murder That Never Was (Forensic Instincts #5)', 'price': 'Â£54.11', 'availability': 'In stock'}
# {'title': "The Most Perfect Thing: Inside (and Outside) a Bird's Egg", 'price': 'Â£42.96', 'availability': 'In stock'}
# {'title': 'The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy', 'price': 'Â£23.89', 'availability': 'In stock'}
# {'title': 'The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing', 'price': 'Â£16.77', 'availability': 'In stock'}
# {'title': 'The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer', 'price': 'Â£20.59', 'availability': 'In stock'}
# {'title': 'The Gutsy Girl: Escapades for Your Life of Epic Adventure', 'price': 'Â£37.13', 'availability': 'In stock'}
# {'title': 'The Electric Pencil: Drawings from Inside State Hospital No. 3', 'price': 'Â£56.06', 'availability': 'In stock'}
# {'title': 'The Death of Humanity: and the Case for Life', 'price': 'Â£58.11', 'availability': 'In stock'}
# {'title': 'The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life', 'price': 'Â£49.05', 'availability': 'In stock'}
# {'title': 'The Art Forger', 'price': 'Â£40.76', 'availability': 'In stock'}
# {'title': 'The Age of Genius: The Seventeenth Century and the Birth of the Modern Mind', 'price': 'Â£19.73', 'availability': 'In stock'}
# {'title': "The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution", 'price': 'Â£32.24', 'availability': 'In stock'}
# {'title': 'Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up', 'price': 'Â£41.83', 'availability': 'In stock'}
# {'title': 'Soul Reader', 'price': 'Â£39.58', 'availability': 'In stock'}
# {'title': 'Security', 'price': 'Â£39.25', 'availability': 'In stock'}
# {'title': 'Saga, Volume 6 (Saga (Collected Editions) #6)', 'price': 'Â£25.02', 'availability': 'In stock'}
# {'title': 'Saga, Volume 5 (Saga (Collected Editions) #5)', 'price': 'Â£51.04', 'availability': 'In stock'}
# {'title': 'Reskilling America: Learning to Labor in the Twenty-First Century', 'price': 'Â£19.83', 'availability': 'In stock'}
# {'title': 'Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) #11-15)', 'price': 'Â£50.40', 'availability': 'In stock'}
# {'title': 'Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)', 'price': 'Â£13.61', 'availability': 'In stock'}
# {'title': 'Princess Between Worlds (Wide-Awake Princess #5)', 'price': 'Â£13.34', 'availability': 'In stock'}
# {'title': 'Pop Gun War, Volume 1: Gift', 'price': 'Â£18.97', 'availability': 'In stock'}
# {'title': 'Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics', 'price': 'Â£36.28', 'availability': 'In stock'}
# {'title': 'Patience', 'price': 'Â£10.16', 'availability': 'In stock'}
# {'title': 'Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)', 'price': 'Â£15.44', 'availability': 'In stock'}
# {'title': 'orange: The Complete Collection 1 (orange: The Complete Collection #1)', 'price': 'Â£48.41', 'availability': 'In stock'}
# {'title': 'Online Marketing for Busy Authors: A Step-By-Step Guide', 'price': 'Â£46.35', 'availability': 'In stock'}
# {'title': 'On a Midnight Clear', 'price': 'Â£14.07', 'availability': 'In stock'}
# {'title': 'Obsidian (Lux #1)', 'price': 'Â£14.86', 'availability': 'In stock'}
# {'title': 'My Paris Kitchen: Recipes and Stories', 'price': 'Â£33.37', 'availability': 'In stock'}
# {'title': 'Masks and Shadows', 'price': 'Â£56.40', 'availability': 'In stock'}
# {'title': 'Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed', 'price': 'Â£14.02', 'availability': 'In stock'}
# {'title': 'Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)', 'price': 'Â£46.91', 'availability': 'In stock'}
# {'title': 'Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)', 'price': 'Â£45.61', 'availability': 'In stock'}
# {'title': 'Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)', 'price': 'Â£19.92', 'availability': 'In stock'}
# {'title': 'Layered: Baking, Building, and Styling Spectacular Cakes', 'price': 'Â£40.11', 'availability': 'In stock'}
# {'title': 'Judo: Seven Steps to Black Belt (an Introductory Guide for Beginners)', 'price': 'Â£53.90', 'availability': 'In stock'}
# {'title': 'Join', 'price': 'Â£35.67', 'availability': 'In stock'}
# {'title': 'In the Country We Love: My Family Divided', 'price': 'Â£22.00', 'availability': 'In stock'}
# {'title': 'Immunity: How Elie Metchnikoff Changed the Course of Modern Medicine', 'price': 'Â£57.36', 'availability': 'In stock'}
# {'title': 'I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland (Compilations) #1-5)', 'price': 'Â£29.17', 'availability': 'In stock'}
# {'title': 'I am a Hero Omnibus Volume 1', 'price': 'Â£54.63', 'availability': 'In stock'}
# {'title': 'How to Be Miserable: 40 Strategies You Already Use', 'price': 'Â£46.03', 'availability': 'In stock'}
# {'title': 'Her Backup Boyfriend (The Sorensen Family #1)', 'price': 'Â£33.97', 'availability': 'In stock'}
# {'title': 'Giant Days, Vol. 2 (Giant Days #5-8)', 'price': 'Â£22.11', 'availability': 'In stock'}
# {'title': 'Forever and Forever: The Courtship of Henry Longfellow and Fanny Appleton', 'price': 'Â£29.69', 'availability': 'In stock'}
# {'title': 'First and First (Five Boroughs #3)', 'price': 'Â£15.97', 'availability': 'In stock'}
# {'title': 'Fifty Shades Darker (Fifty Shades #2)', 'price': 'Â£21.96', 'availability': 'In stock'}
# {'title': 'Everydata: The Misinformation Hidden in the Little Data You Consume Every Day', 'price': 'Â£54.35', 'availability': 'In stock'}
# {'title': "Don't Be a Jerk: And Other Practical Advice from Dogen, Japan's Greatest Zen Master", 'price': 'Â£37.97', 'availability': 'In stock'}
# {'title': 'Danganronpa Volume 1', 'price': 'Â£51.99', 'availability': 'In stock'}
# {'title': 'Crown of Midnight (Throne of Glass #2)', 'price': 'Â£43.29', 'availability': 'In stock'}
# {'title': 'Codename Baboushka, Volume 1: The Conclave of Death', 'price': 'Â£36.72', 'availability': 'In stock'}
# {'title': 'Camp Midnight', 'price': 'Â£17.08', 'availability': 'In stock'}
# {'title': 'Call the Nurse: True Stories of a Country Nurse on a Scottish Isle', 'price': 'Â£29.14', 'availability': 'In stock'}
# {'title': 'Burning', 'price': 'Â£28.81', 'availability': 'In stock'}
# {'title': 'Bossypants', 'price': 'Â£49.46', 'availability': 'In stock'}
# {'title': 'Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet (Collected Editions))', 'price': 'Â£37.92', 'availability': 'In stock'}
# {'title': 'Avatar: The Last Airbender: Smoke and Shadow, Part 3 (Smoke and Shadow #3)', 'price': 'Â£28.09', 'availability': 'In stock'}
# {'title': 'Algorithms to Live By: The Computer Science of Human Decisions', 'price': 'Â£30.81', 'availability': 'In stock'}
# {'title': 'A World of Flavor: Your Gluten Free Passport', 'price': 'Â£42.95', 'availability': 'In stock'}
# {'title': 'A Piece of Sky, a Grain of Rice: A Memoir in Four Meditations', 'price': 'Â£56.76', 'availability': 'In stock'}
# {'title': 'A Murder in Time', 'price': 'Â£16.64', 'availability': 'In stock'}
# {'title': 'A Flight of Arrows (The Pathfinders #2)', 'price': 'Â£55.53', 'availability': 'In stock'}
# {'title': 'A Fierce and Subtle Poison', 'price': 'Â£28.13', 'availability': 'In stock'}
# {'title': 'A Court of Thorns and Roses (A Court of Thorns and Roses #1)', 'price': 'Â£52.37', 'availability': 'In stock'}
# {'title': '(Un)Qualified: How God Uses Broken People to Do Big Things', 'price': 'Â£54.00', 'availability': 'In stock'}
# {'title': 'You Are What You Love: The Spiritual Power of Habit', 'price': 'Â£21.87', 'availability': 'In stock'}
# {'title': "William Shakespeare's Star Wars: Verily, A New Hope (William Shakespeare's Star Wars #4)", 'price': 'Â£43.30', 'availability': 'In stock'}
# {'title': 'Tuesday Nights in 1980', 'price': 'Â£21.04', 'availability': 'In stock'}
# {'title': 'Tracing Numbers on a Train', 'price': 'Â£41.60', 'availability': 'In stock'}
# {'title': 'Throne of Glass (Throne of Glass #1)', 'price': 'Â£35.07', 'availability': 'In stock'}
# {'title': 'Thomas Jefferson and the Tripoli Pirates: The Forgotten War That Changed American History', 'price': 'Â£59.64', 'availability': 'In stock'}
# {'title': 'Thirteen Reasons Why', 'price': 'Â£52.72', 'availability': 'In stock'}
# {'title': 'The White Cat and the Monk: A Retelling of the Poem â\x80\x9cPangur BÃ¡nâ\x80\x9d', 'price': 'Â£58.08', 'availability': 'In stock'}
# {'title': 'The Wedding Dress', 'price': 'Â£24.12', 'availability': 'In stock'}
# {'title': 'The Vacationers', 'price': 'Â£42.15', 'availability': 'In stock'}
# {'title': 'The Third Wave: An Entrepreneurâ\x80\x99s Vision of the Future', 'price': 'Â£12.61', 'availability': 'In stock'}
# {'title': 'The Stranger', 'price': 'Â£17.44', 'availability': 'In stock'}
# {'title': 'The Shadow Hero (The Shadow Hero)', 'price': 'Â£33.14', 'availability': 'In stock'}
# {'title': 'The Secret (The Secret #1)', 'price': 'Â£27.37', 'availability': 'In stock'}
# {'title': 'The Regional Office Is Under Attack!', 'price': 'Â£51.36', 'availability': 'In stock'}
# {'title': 'The Psychopath Test: A Journey Through the Madness Industry', 'price': 'Â£36.00', 'availability': 'In stock'}
# {'title': 'The Project', 'price': 'Â£10.65', 'availability': 'In stock'}
# {'title': 'The Power of Now: A Guide to Spiritual Enlightenment', 'price': 'Â£43.54', 'availability': 'In stock'}
# {'title': "The Omnivore's Dilemma: A Natural History of Four Meals", 'price': 'Â£38.21', 'availability': 'In stock'}
# {'title': 'The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us', 'price': 'Â£37.34', 'availability': 'In stock'}
# {'title': 'The Murder of Roger Ackroyd (Hercule Poirot #4)', 'price': 'Â£44.10', 'availability': 'In stock'}
# {'title': 'The Mistake (Off-Campus #2)', 'price': 'Â£43.29', 'availability': 'In stock'}
# {'title': "The Matchmaker's Playbook (Wingmen Inc. #1)", 'price': 'Â£55.85', 'availability': 'In stock'}
# {'title': 'The Love and Lemons Cookbook: An Apple-to-Zucchini Celebration of Impromptu Cooking', 'price': 'Â£37.60', 'availability': 'In stock'}
# {'title': 'The Long Shadow of Small Ghosts: Murder and Memory in an American City', 'price': 'Â£10.97', 'availability': 'In stock'}
# {'title': 'The Kite Runner', 'price': 'Â£41.82', 'availability': 'In stock'}
# {'title': 'The House by the Lake', 'price': 'Â£36.95', 'availability': 'In stock'}
# {'title': 'The Glittering Court (The Glittering Court #1)', 'price': 'Â£44.28', 'availability': 'In stock'}
# {'title': 'The Girl on the Train', 'price': 'Â£55.02', 'availability': 'In stock'}
# {'title': 'The Genius of Birds', 'price': 'Â£17.24', 'availability': 'In stock'}
# {'title': 'The Emerald Mystery', 'price': 'Â£23.15', 'availability': 'In stock'}
# {'title': 'The Cookies & Cups Cookbook: 125+ sweet & savory recipes reminding you to Always Eat Dessert First', 'price': 'Â£41.25', 'availability': 'In stock'}
# {'title': "The Bridge to Consciousness: I'm Writing the Bridge Between Science and Our Old and New Beliefs.", 'price': 'Â£32.00', 'availability': 'In stock'}
# {'title': "The Artist's Way: A Spiritual Path to Higher Creativity", 'price': 'Â£38.49', 'availability': 'In stock'}
# {'title': 'The Art of War', 'price': 'Â£33.34', 'availability': 'In stock'}
# {'title': 'The Argonauts', 'price': 'Â£10.93', 'availability': 'In stock'}
# {'title': 'The 10% Entrepreneur: Live Your Startup Dream Without Quitting Your Day Job', 'price': 'Â£27.55', 'availability': 'In stock'}
# {'title': 'Suddenly in Love (Lake Haven #1)', 'price': 'Â£55.99', 'availability': 'In stock'}
# {'title': 'Something More Than This', 'price': 'Â£16.24', 'availability': 'In stock'}
# {'title': 'Soft Apocalypse', 'price': 'Â£26.12', 'availability': 'In stock'}
# {'title': "So You've Been Publicly Shamed", 'price': 'Â£12.23', 'availability': 'In stock'}
# {'title': 'Shoe Dog: A Memoir by the Creator of NIKE', 'price': 'Â£23.99', 'availability': 'In stock'}
# {'title': 'Shobu Samurai, Project Aryoku (#3)', 'price': 'Â£29.06', 'availability': 'In stock'}
# {'title': 'Secrets and Lace (Fatal Hearts #1)', 'price': 'Â£20.27', 'availability': 'In stock'}
# {'title': 'Scarlett Epstein Hates It Here', 'price': 'Â£43.55', 'availability': 'In stock'}
# {'title': 'Romero and Juliet: A Tragic Tale of Love and Zombies', 'price': 'Â£36.94', 'availability': 'In stock'}
# {'title': 'Redeeming Love', 'price': 'Â£20.47', 'availability': 'In stock'}
# {'title': 'Poses for Artists Volume 1 - Dynamic and Sitting Poses: An Essential Reference for Figure Drawing and the Human Form', 'price': 'Â£41.06', 'availability': 'In stock'}
# {'title': 'Poems That Make Grown Women Cry', 'price': 'Â£14.19', 'availability': 'In stock'}
# {'title': 'Nightingale, Sing', 'price': 'Â£38.28', 'availability': 'In stock'}
# {'title': 'Night Sky with Exit Wounds', 'price': 'Â£41.05', 'availability': 'In stock'}
# {'title': 'Mrs. Houdini', 'price': 'Â£30.25', 'availability': 'In stock'}
# {'title': 'Modern Romance', 'price': 'Â£28.26', 'availability': 'In stock'}
# {'title': 'Miss Peregrineâ\x80\x99s Home for Peculiar Children (Miss Peregrineâ\x80\x99s Peculiar Children #1)', 'price': 'Â£10.76', 'availability': 'In stock'}
# {'title': 'Louisa: The Extraordinary Life of Mrs. Adams', 'price': 'Â£16.85', 'availability': 'In stock'}
# {'title': 'Little Red', 'price': 'Â£13.47', 'availability': 'In stock'}
# {'title': 'Library of Souls (Miss Peregrineâ\x80\x99s Peculiar Children #3)', 'price': 'Â£48.56', 'availability': 'In stock'}
# {'title': 'Large Print Heart of the Pride', 'price': 'Â£19.15', 'availability': 'In stock'}
# {'title': 'I Had a Nice Time And Other Lies...: How to find love & sh*t like that', 'price': 'Â£57.36', 'availability': 'In stock'}
# {'title': 'Hollow City (Miss Peregrineâ\x80\x99s Peculiar Children #2)', 'price': 'Â£42.98', 'availability': 'In stock'}
# {'title': 'Grumbles', 'price': 'Â£22.16', 'availability': 'In stock'}
# {'title': 'Full Moon over Noahâ\x80\x99s Ark: An Odyssey to Mount Ararat and Beyond', 'price': 'Â£49.43', 'availability': 'In stock'}
# {'title': 'Frostbite (Vampire Academy #2)', 'price': 'Â£29.99', 'availability': 'In stock'}
# {'title': 'Follow You Home', 'price': 'Â£21.36', 'availability': 'In stock'}
# {'title': 'First Steps for New Christians (Print Edition)', 'price': 'Â£29.00', 'availability': 'In stock'}
# {'title': 'Finders Keepers (Bill Hodges Trilogy #2)', 'price': 'Â£53.53', 'availability': 'In stock'}
# {'title': 'Fables, Vol. 1: Legends in Exile (Fables #1)', 'price': 'Â£41.62', 'availability': 'In stock'}
# {'title': 'Eureka Trivia 6.0', 'price': 'Â£54.59', 'availability': 'In stock'}
# {'title': 'Drive: The Surprising Truth About What Motivates Us', 'price': 'Â£34.95', 'availability': 'In stock'}
# {'title': 'Done Rubbed Out (Reightman & Bailey #1)', 'price': 'Â£37.72', 'availability': 'In stock'}
# {'title': 'Doing It Over (Most Likely To #1)', 'price': 'Â£35.61', 'availability': 'In stock'}
# {'title': 'Deliciously Ella Every Day: Quick and Easy Recipes for Gluten-Free Snacks, Packed Lunches, and Simple Meals', 'price': 'Â£42.16', 'availability': 'In stock'}
# {'title': 'Dark Notes', 'price': 'Â£19.19', 'availability': 'In stock'}
# {'title': 'Daring Greatly: How the Courage to Be Vulnerable Transforms the Way We Live, Love, Parent, and Lead', 'price': 'Â£19.43', 'availability': 'In stock'}
# {'title': 'Close to You', 'price': 'Â£49.46', 'availability': 'In stock'}
# {'title': 'Chasing Heaven: What Dying Taught Me About Living', 'price': 'Â£37.80', 'availability': 'In stock'}
# {'title': 'Big Magic: Creative Living Beyond Fear', 'price': 'Â£30.80', 'availability': 'In stock'}
# {'title': 'Becoming Wise: An Inquiry into the Mystery and Art of Living', 'price': 'Â£27.43', 'availability': 'In stock'}
# {'title': 'Beauty Restored (Riley Family Legacy Novellas #3)', 'price': 'Â£11.11', 'availability': 'In stock'}
# {'title': 'Batman: The Long Halloween (Batman)', 'price': 'Â£36.50', 'availability': 'In stock'}
# {'title': 'Batman: The Dark Knight Returns (Batman)', 'price': 'Â£15.38', 'availability': 'In stock'}
# {'title': "Ayumi's Violin", 'price': 'Â£15.48', 'availability': 'In stock'}
# {'title': 'Anonymous', 'price': 'Â£46.82', 'availability': 'In stock'}
# {'title': 'Amy Meets the Saints and Sages', 'price': 'Â£18.46', 'availability': 'In stock'}
# {'title': 'Amid the Chaos', 'price': 'Â£36.58', 'availability': 'In stock'}
# {'title': 'Amatus', 'price': 'Â£50.54', 'availability': 'In stock'}
# {'title': 'Agnostic: A Spirited Manifesto', 'price': 'Â£12.51', 'availability': 'In stock'}
# {'title': 'Zealot: The Life and Times of Jesus of Nazareth', 'price': 'Â£24.70', 'availability': 'In stock'}
# {'title': 'You (You #1)', 'price': 'Â£43.61', 'availability': 'In stock'}
# {'title': 'Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1)', 'price': 'Â£37.34', 'availability': 'In stock'}
# {'title': 'Wild Swans', 'price': 'Â£14.36', 'availability': 'In stock'}
# {'title': 'Why the Right Went Wrong: Conservatism--From Goldwater to the Tea Party and Beyond', 'price': 'Â£52.65', 'availability': 'In stock'}
# {'title': 'Whole Lotta Creativity Going On: 60 Fun and Unusual Exercises to Awaken and Strengthen Your Creativity', 'price': 'Â£38.20', 'availability': 'In stock'}
# {'title': "What's It Like in Space?: Stories from Astronauts Who've Been There", 'price': 'Â£19.60', 'availability': 'In stock'}
# {'title': 'We Are Robin, Vol. 1: The Vigilante Business (We Are Robin #1)', 'price': 'Â£53.90', 'availability': 'In stock'}
# {'title': "Walt Disney's Alice in Wonderland", 'price': 'Â£12.96', 'availability': 'In stock'}
# {'title': 'V for Vendetta (V for Vendetta Complete)', 'price': 'Â£37.10', 'availability': 'In stock'}
# {'title': 'Until Friday Night (The Field Party #1)', 'price': 'Â£46.31', 'availability': 'In stock'}
# {'title': 'Unbroken: A World War II Story of Survival, Resilience, and Redemption', 'price': 'Â£45.95', 'availability': 'In stock'}
# {'title': 'Twenty Yawns', 'price': 'Â£22.08', 'availability': 'In stock'}
# {'title': 'Through the Woods', 'price': 'Â£25.38', 'availability': 'In stock'}
# {'title': 'This Is Where It Ends', 'price': 'Â£27.12', 'availability': 'In stock'}
# {'title': 'The Year of Magical Thinking', 'price': 'Â£43.04', 'availability': 'In stock'}
# {'title': 'The Wright Brothers', 'price': 'Â£56.80', 'availability': 'In stock'}
# {'title': "The White Queen (The Cousins' War #1)", 'price': 'Â£25.91', 'availability': 'In stock'}
# {'title': "The Wedding Pact (The O'Malleys #2)", 'price': 'Â£32.61', 'availability': 'In stock'}
# {'title': 'The Time Keeper', 'price': 'Â£27.88', 'availability': 'In stock'}
# {'title': 'The Testament of Mary', 'price': 'Â£52.67', 'availability': 'In stock'}
# {'title': 'The Star-Touched Queen', 'price': 'Â£46.02', 'availability': 'In stock'}
# {'title': 'The Songs of the Gods', 'price': 'Â£44.48', 'availability': 'In stock'}
# {'title': 'The Song of Achilles', 'price': 'Â£37.40', 'availability': 'In stock'}
# {'title': 'The Rosie Project (Don Tillman #1)', 'price': 'Â£54.04', 'availability': 'In stock'}
# {'title': 'The Power of Habit: Why We Do What We Do in Life and Business', 'price': 'Â£16.88', 'availability': 'In stock'}
# {'title': 'The Marriage of Opposites', 'price': 'Â£28.08', 'availability': 'In stock'}
# {'title': 'The Lucifer Effect: Understanding How Good People Turn Evil', 'price': 'Â£10.40', 'availability': 'In stock'}
# {'title': 'The Long Haul (Diary of a Wimpy Kid #9)', 'price': 'Â£44.07', 'availability': 'In stock'}
# {'title': 'The Loney', 'price': 'Â£23.40', 'availability': 'In stock'}
# {'title': 'The Literature Book (Big Ideas Simply Explained)', 'price': 'Â£17.43', 'availability': 'In stock'}
# {'title': 'The Last Mile (Amos Decker #2)', 'price': 'Â£54.21', 'availability': 'In stock'}
# {'title': 'The Immortal Life of Henrietta Lacks', 'price': 'Â£40.67', 'availability': 'In stock'}
# {'title': 'The Hidden Oracle (The Trials of Apollo #1)', 'price': 'Â£52.26', 'availability': 'In stock'}
# {'title': 'The Help Yourself Cookbook for Kids: 60 Easy Plant-Based Recipes Kids Can Make to Stay Healthy and Save the Earth', 'price': 'Â£28.77', 'availability': 'In stock'}
# {'title': 'The Guilty (Will Robie #4)', 'price': 'Â£13.82', 'availability': 'In stock'}
# {'title': 'The First Hostage (J.B. Collins #2)', 'price': 'Â£25.85', 'availability': 'In stock'}
# {'title': 'The Dovekeepers', 'price': 'Â£48.78', 'availability': 'In stock'}
# {'title': 'The Darkest Lie', 'price': 'Â£35.35', 'availability': 'In stock'}
# {'title': 'The Bane Chronicles (The Bane Chronicles #1-11)', 'price': 'Â£44.73', 'availability': 'In stock'}
# {'title': 'The Bad-Ass Librarians of Timbuktu: And Their Race to Save the Worldâ\x80\x99s Most Precious Manuscripts', 'price': 'Â£15.77', 'availability': 'In stock'}
# {'title': 'The 14th Colony (Cotton Malone #11)', 'price': 'Â£39.24', 'availability': 'In stock'}
# {'title': 'That Darkness (Gardiner and Renner #1)', 'price': 'Â£13.92', 'availability': 'In stock'}
# {'title': 'Tastes Like Fear (DI Marnie Rome #3)', 'price': 'Â£10.69', 'availability': 'In stock'}
# {'title': 'Take Me with You', 'price': 'Â£45.21', 'availability': 'In stock'}
# {'title': 'Swell: A Year of Waves', 'price': 'Â£45.58', 'availability': 'In stock'}
# {'title': 'Superman Vol. 1: Before Truth (Superman by Gene Luen Yang #1)', 'price': 'Â£11.89', 'availability': 'In stock'}
# {'title': 'Still Life with Bread Crumbs', 'price': 'Â£26.41', 'availability': 'In stock'}
# {'title': 'Steve Jobs', 'price': 'Â£39.50', 'availability': 'In stock'}
# {'title': 'Sorting the Beef from the Bull: The Science of Food Fraud Forensics', 'price': 'Â£44.74', 'availability': 'In stock'}
# {'title': 'Someone Like You (The Harrisons #2)', 'price': 'Â£52.79', 'availability': 'In stock'}
# {'title': 'So Cute It Hurts!!, Vol. 6 (So Cute It Hurts!! #6)', 'price': 'Â£35.43', 'availability': 'In stock'}
# {'title': 'Shtum', 'price': 'Â£55.84', 'availability': 'In stock'}
# {'title': 'See America: A Celebration of Our National Parks & Treasured Sites', 'price': 'Â£48.87', 'availability': 'In stock'}
# {'title': 'salt.', 'price': 'Â£46.78', 'availability': 'In stock'}
# {'title': 'Robin War', 'price': 'Â£47.82', 'availability': 'In stock'}
# {'title': 'Red Hood/Arsenal, Vol. 1: Open for Business (Red Hood/Arsenal #1)', 'price': 'Â£25.48', 'availability': 'In stock'}
# {'title': 'Rain Fish', 'price': 'Â£23.57', 'availability': 'In stock'}
# {'title': 'Quarter Life Poetry: Poems for the Young, Broke and Hangry', 'price': 'Â£50.89', 'availability': 'In stock'}
# {'title': 'Pet Sematary', 'price': 'Â£10.56', 'availability': 'In stock'}
# {'title': 'Overload: How to Unplug, Unwind, and Unleash Yourself from the Pressure of Stress', 'price': 'Â£52.15', 'availability': 'In stock'}
# {'title': 'Once Was a Time', 'price': 'Â£18.28', 'availability': 'In stock'}
# {'title': 'Old School (Diary of a Wimpy Kid #10)', 'price': 'Â£11.83', 'availability': 'In stock'}
# {'title': 'No Dream Is Too High: Life Lessons From a Man Who Walked on the Moon', 'price': 'Â£21.95', 'availability': 'In stock'}
# {'title': 'Naruto (3-in-1 Edition), Vol. 14: Includes Vols. 40, 41 & 42 (Naruto: Omnibus #14)', 'price': 'Â£38.39', 'availability': 'In stock'}
# {'title': 'My Name Is Lucy Barton', 'price': 'Â£41.56', 'availability': 'In stock'}
# {'title': 'My Mrs. Brown', 'price': 'Â£24.48', 'availability': 'In stock'}
# {'title': 'My Kind of Crazy', 'price': 'Â£40.36', 'availability': 'In stock'}
# {'title': 'Mr. Mercedes (Bill Hodges Trilogy #1)', 'price': 'Â£28.90', 'availability': 'In stock'}
# {'title': 'More Than Music (Chasing the Dream #1)', 'price': 'Â£37.61', 'availability': 'In stock'}
# {'title': 'Made to Stick: Why Some Ideas Survive and Others Die', 'price': 'Â£38.85', 'availability': 'In stock'}
# {'title': 'Luis Paints the World', 'price': 'Â£53.95', 'availability': 'In stock'}
# {'title': 'Luckiest Girl Alive', 'price': 'Â£49.83', 'availability': 'In stock'}
# {'title': 'Lowriders to the Center of the Earth (Lowriders in Space #2)', 'price': 'Â£51.51', 'availability': 'In stock'}
# {'title': 'Love Is a Mix Tape (Music #1)', 'price': 'Â£18.03', 'availability': 'In stock'}
# {'title': 'Looking for Lovely: Collecting the Moments that Matter', 'price': 'Â£29.14', 'availability': 'In stock'}
# {'title': 'Living Leadership by Insight: A Good Leader Achieves, a Great Leader Builds Monuments', 'price': 'Â£46.91', 'availability': 'In stock'}
# {'title': 'Let It Out: A Journey Through Journaling', 'price': 'Â£26.79', 'availability': 'In stock'}
# {'title': 'Lady Midnight (The Dark Artifices #1)', 'price': 'Â£16.28', 'availability': 'In stock'}
# {'title': "It's All Easy: Healthy, Delicious Weeknight Meals in under 30 Minutes", 'price': 'Â£19.55', 'availability': 'In stock'}
# {'title': 'Island of Dragons (Unwanteds #7)', 'price': 'Â£29.65', 'availability': 'In stock'}
# {'title': "I Know What I'm Doing -- and Other Lies I Tell Myself: Dispatches from a Life Under Construction", 'price': 'Â£25.98', 'availability': 'In stock'}
# {'title': 'I Am Pilgrim (Pilgrim #1)', 'price': 'Â£10.60', 'availability': 'In stock'}
# {'title': 'Hyperbole and a Half: Unfortunate Situations, Flawed Coping Mechanisms, Mayhem, and Other Things That Happened', 'price': 'Â£14.75', 'availability': 'In stock'}
# {'title': 'Hush, Hush (Hush, Hush #1)', 'price': 'Â£47.02', 'availability': 'In stock'}
# {'title': 'Hold Your Breath (Search and Rescue #1)', 'price': 'Â£28.82', 'availability': 'In stock'}
# {'title': 'Hamilton: The Revolution', 'price': 'Â£58.79', 'availability': 'In stock'}
# {'title': 'Greek Mythic History', 'price': 'Â£10.23', 'availability': 'In stock'}
# {'title': 'God: The Most Unpleasant Character in All Fiction', 'price': 'Â£30.03', 'availability': 'In stock'}
# {'title': 'Glory over Everything: Beyond The Kitchen House', 'price': 'Â£45.84', 'availability': 'In stock'}
# {'title': 'Feathers: Displays of Brilliant Plumage', 'price': 'Â£49.05', 'availability': 'In stock'}
# {'title': 'Far & Away: Places on the Brink of Change: Seven Continents, Twenty-Five Years', 'price': 'Â£15.06', 'availability': 'In stock'}
# {'title': 'Every Last Word', 'price': 'Â£46.47', 'availability': 'In stock'}
# {'title': 'Eligible (The Austen Project #4)', 'price': 'Â£27.09', 'availability': 'In stock'}
# {'title': 'El Deafo', 'price': 'Â£57.62', 'availability': 'In stock'}
# {'title': 'Eight Hundred Grapes', 'price': 'Â£14.39', 'availability': 'In stock'}
# {'title': 'Eaternity: More than 150 Deliciously Easy Vegan Recipes for a Long, Healthy, Satisfied, Joyful Life', 'price': 'Â£51.75', 'availability': 'In stock'}
# {'title': 'Eat Fat, Get Thin', 'price': 'Â£54.07', 'availability': 'In stock'}
# {'title': "Don't Get Caught", 'price': 'Â£55.35', 'availability': 'In stock'}
# {'title': 'Doctor Sleep (The Shining #2)', 'price': 'Â£40.12', 'availability': 'In stock'}
# {'title': 'Demigods & Magicians: Percy and Annabeth Meet the Kanes (Percy Jackson & Kane Chronicles Crossover #1-3)', 'price': 'Â£37.51', 'availability': 'In stock'}
# {'title': 'Dear Mr. Knightley', 'price': 'Â£11.21', 'availability': 'In stock'}
# {'title': 'Daily Fantasy Sports', 'price': 'Â£36.58', 'availability': 'In stock'}
# {'title': 'Crazy Love: Overwhelmed by a Relentless God', 'price': 'Â£47.72', 'availability': 'In stock'}
# {'title': 'Cometh the Hour (The Clifton Chronicles #6)', 'price': 'Â£25.01', 'availability': 'In stock'}
# {'title': 'Code Name Verity (Code Name Verity #1)', 'price': 'Â£22.13', 'availability': 'In stock'}
# {'title': 'Clockwork Angel (The Infernal Devices #1)', 'price': 'Â£44.14', 'availability': 'In stock'}
# {'title': 'City of Glass (The Mortal Instruments #3)', 'price': 'Â£56.02', 'availability': 'In stock'}
# {'title': 'City of Fallen Angels (The Mortal Instruments #4)', 'price': 'Â£11.23', 'availability': 'In stock'}
# {'title': 'City of Bones (The Mortal Instruments #1)', 'price': 'Â£43.28', 'availability': 'In stock'}
# {'title': 'City of Ashes (The Mortal Instruments #2)', 'price': 'Â£47.27', 'availability': 'In stock'}
# {'title': 'Cell', 'price': 'Â£20.29', 'availability': 'In stock'}
# {'title': 'Catching Jordan (Hundred Oaks)', 'price': 'Â£50.83', 'availability': 'In stock'}
# {'title': 'Carry On, Warrior: Thoughts on Life Unarmed', 'price': 'Â£31.85', 'availability': 'In stock'}
# {'title': 'Carrie', 'price': 'Â£46.23', 'availability': 'In stock'}
# {'title': 'Buying In: The Secret Dialogue Between What We Buy and Who We Are', 'price': 'Â£37.80', 'availability': 'In stock'}
# {'title': 'Brain on Fire: My Month of Madness', 'price': 'Â£49.32', 'availability': 'In stock'}
# {'title': 'Batman: Europa', 'price': 'Â£32.01', 'availability': 'In stock'}
# {'title': 'Barefoot Contessa Back to Basics', 'price': 'Â£28.01', 'availability': 'In stock'}
# {'title': "Barefoot Contessa at Home: Everyday Recipes You'll Make Over and Over Again", 'price': 'Â£50.62', 'availability': 'In stock'}
# {'title': 'Balloon Animals', 'price': 'Â£17.03', 'availability': 'In stock'}
# {'title': 'Art Ops Vol. 1', 'price': 'Â£48.80', 'availability': 'In stock'}
# {'title': 'Aristotle and Dante Discover the Secrets of the Universe (Aristotle and Dante Discover the Secrets of the Universe #1)', 'price': 'Â£58.14', 'availability': 'In stock'}
# {'title': 'Angels Walking (Angels Walking #1)', 'price': 'Â£34.20', 'availability': 'In stock'}
# {'title': 'Angels & Demons (Robert Langdon #1)', 'price': 'Â£51.48', 'availability': 'In stock'}
# {'title': 'All the Light We Cannot See', 'price': 'Â£29.87', 'availability': 'In stock'}
# {'title': 'Adulthood Is a Myth: A "Sarah\'s Scribbles" Collection', 'price': 'Â£10.90', 'availability': 'In stock'}
# {'title': 'Abstract City', 'price': 'Â£56.37', 'availability': 'In stock'}
# {'title': 'A Time of Torment (Charlie Parker #14)', 'price': 'Â£48.35', 'availability': 'In stock'}
# {'title': 'A Study in Scarlet (Sherlock Holmes #1)', 'price': 'Â£16.73', 'availability': 'In stock'}
# {'title': 'A Series of Catastrophes and Miracles: A True Story of Love, Science, and Cancer', 'price': 'Â£56.48', 'availability': 'In stock'}
# {'title': "A People's History of the United States", 'price': 'Â£40.79', 'availability': 'In stock'}
# {'title': 'A Man Called Ove', 'price': 'Â£39.72', 'availability': 'In stock'}
# {'title': 'A Distant Mirror: The Calamitous 14th Century', 'price': 'Â£14.58', 'availability': 'In stock'}
# {'title': 'A Brush of Wings (Angels Walking #3)', 'price': 'Â£55.51', 'availability': 'In stock'}
# {'title': '1491: New Revelations of the Americas Before Columbus', 'price': 'Â£21.80', 'availability': 'In stock'}
# {'title': 'The Three Searches, Meaning, and the Story', 'price': 'Â£13.33', 'availability': 'In stock'}
# {'title': 'Searching for Meaning in Gailana', 'price': 'Â£38.73', 'availability': 'In stock'}
# {'title': 'Rook', 'price': 'Â£37.86', 'availability': 'In stock'}
# {'title': 'My Kitchen Year: 136 Recipes That Saved My Life', 'price': 'Â£11.53', 'availability': 'In stock'}
# {'title': '13 Hours: The Inside Account of What Really Happened In Benghazi', 'price': 'Â£27.06', 'availability': 'In stock'}
# {'title': "Will You Won't You Want Me?", 'price': 'Â£13.86', 'availability': 'In stock'}
# {'title': 'Tipping Point for Planet Earth: How Close Are We to the Edge?', 'price': 'Â£37.55', 'availability': 'In stock'}
# {'title': 'The Star-Touched Queen', 'price': 'Â£32.30', 'availability': 'In stock'}
# {'title': 'The Silent Sister (Riley MacPherson #1)', 'price': 'Â£46.29', 'availability': 'In stock'}
# {'title': 'The Midnight Watch: A Novel of the Titanic and the Californian', 'price': 'Â£26.20', 'availability': 'In stock'}
# {'title': 'The Lonely City: Adventures in the Art of Being Alone', 'price': 'Â£33.26', 'availability': 'In stock'}
# {'title': 'The Gray Rhino: How to Recognize and Act on the Obvious Dangers We Ignore', 'price': 'Â£59.15', 'availability': 'In stock'}
# {'title': 'The Golden Condom: And Other Essays on Love Lost and Found', 'price': 'Â£39.43', 'availability': 'In stock'}
# {'title': 'The Epidemic (The Program 0.6)', 'price': 'Â£14.44', 'availability': 'In stock'}
# {'title': 'The Dinner Party', 'price': 'Â£56.54', 'availability': 'In stock'}
# {'title': 'The Diary of a Young Girl', 'price': 'Â£59.90', 'availability': 'In stock'}
# {'title': 'The Children', 'price': 'Â£11.88', 'availability': 'In stock'}
# {'title': 'Stars Above (The Lunar Chronicles #4.5)', 'price': 'Â£48.05', 'availability': 'In stock'}
# {'title': 'Snatched: How A Drug Queen Went Undercover for the DEA and Was Kidnapped By Colombian Guerillas', 'price': 'Â£21.21', 'availability': 'In stock'}
# {'title': 'Raspberry Pi Electronics Projects for the Evil Genius', 'price': 'Â£49.67', 'availability': 'In stock'}
# {'title': 'Quench Your Own Thirst: Business Lessons Learned Over a Beer or Two', 'price': 'Â£43.14', 'availability': 'In stock'}
# {'title': 'Psycho: Sanitarium (Psycho #1.5)', 'price': 'Â£36.97', 'availability': 'In stock'}
# {'title': 'Poisonous (Max Revere Novels #3)', 'price': 'Â£26.80', 'availability': 'In stock'}
# {'title': 'One with You (Crossfire #5)', 'price': 'Â£15.71', 'availability': 'In stock'}
# {'title': 'No Love Allowed (Dodge Cove #1)', 'price': 'Â£54.65', 'availability': 'In stock'}
# {'title': 'Murder at the 42nd Street Library (Raymond Ambler #1)', 'price': 'Â£54.36', 'availability': 'In stock'}
# {'title': 'Most Wanted', 'price': 'Â£35.28', 'availability': 'In stock'}
# {'title': 'Love, Lies and Spies', 'price': 'Â£20.55', 'availability': 'In stock'}
# {'title': 'How to Speak Golf: An Illustrated Guide to Links Lingo', 'price': 'Â£58.32', 'availability': 'In stock'}
# {'title': 'Hide Away (Eve Duncan #20)', 'price': 'Â£11.84', 'availability': 'In stock'}
# {'title': 'Furiously Happy: A Funny Book About Horrible Things', 'price': 'Â£41.46', 'availability': 'In stock'}
# {'title': 'Everyday Italian: 125 Simple and Delicious Recipes', 'price': 'Â£20.10', 'availability': 'In stock'}
# {'title': "Equal Is Unfair: America's Misguided Fight Against Income Inequality", 'price': 'Â£56.86', 'availability': 'In stock'}
# {'title': 'Eleanor & Park', 'price': 'Â£56.51', 'availability': 'In stock'}
# {'title': 'Dirty (Dive Bar #1)', 'price': 'Â£40.83', 'availability': 'In stock'}
# {'title': 'Can You Keep a Secret? (Fear Street Relaunch #4)', 'price': 'Â£48.64', 'availability': 'In stock'}
# {'title': 'Boar Island (Anna Pigeon #19)', 'price': 'Â£59.48', 'availability': 'In stock'}
# {'title': 'A Paris Apartment', 'price': 'Â£39.01', 'availability': 'In stock'}
# {'title': 'A la Mode: 120 Recipes in 60 Pairings: Pies, Tarts, Cakes, Crisps, and More Topped with Ice Cream, Gelato, Frozen Custard, and More', 'price': 'Â£38.77', 'availability': 'In stock'}
# {'title': 'Troublemaker: Surviving Hollywood and Scientology', 'price': 'Â£48.39', 'availability': 'In stock'}
# {'title': 'The Widow', 'price': 'Â£27.26', 'availability': 'In stock'}
# {'title': 'The Sleep Revolution: Transforming Your Life, One Night at a Time', 'price': 'Â£11.68', 'availability': 'In stock'}
# {'title': 'The Improbability of Love', 'price': 'Â£59.45', 'availability': 'In stock'}
# {'title': 'The Art of Startup Fundraising', 'price': 'Â£21.00', 'availability': 'In stock'}
# {'title': 'Take Me Home Tonight (Rock Star Romance #3)', 'price': 'Â£53.98', 'availability': 'In stock'}
# {'title': 'Sleeping Giants (Themis Files #1)', 'price': 'Â£48.74', 'availability': 'In stock'}
# {'title': 'Setting the World on Fire: The Brief, Astonishing Life of St. Catherine of Siena', 'price': 'Â£21.15', 'availability': 'In stock'}
# {'title': 'Playing with Fire', 'price': 'Â£13.71', 'availability': 'In stock'}
# {'title': 'Off the Hook (Fishing for Trouble #1)', 'price': 'Â£47.67', 'availability': 'In stock'}
# {'title': 'Mothering Sunday', 'price': 'Â£13.34', 'availability': 'In stock'}
# {'title': 'Mother, Can You Not?', 'price': 'Â£16.89', 'availability': 'In stock'}
# {'title': 'M Train', 'price': 'Â£27.18', 'availability': 'In stock'}
# {'title': 'Lilac Girls', 'price': 'Â£17.28', 'availability': 'In stock'}
# {'title': 'Lies and Other Acts of Love', 'price': 'Â£45.14', 'availability': 'In stock'}
# {'title': 'Lab Girl', 'price': 'Â£40.85', 'availability': 'In stock'}
# {'title': 'Keep Me Posted', 'price': 'Â£20.46', 'availability': 'In stock'}
# {'title': "It Didn't Start with You: How Inherited Family Trauma Shapes Who We Are and How to End the Cycle", 'price': 'Â£56.27', 'availability': 'In stock'}
# {'title': 'Grey (Fifty Shades #4)', 'price': 'Â£48.49', 'availability': 'In stock'}
# {'title': 'Exit, Pursued by a Bear', 'price': 'Â£51.34', 'availability': 'In stock'}
# {'title': 'Daredevils', 'price': 'Â£16.34', 'availability': 'In stock'}
# {'title': 'Cravings: Recipes for What You Want to Eat', 'price': 'Â£20.50', 'availability': 'In stock'}
# {'title': 'Born for This: How to Find the Work You Were Meant to Do', 'price': 'Â£21.59', 'availability': 'In stock'}
# {'title': 'Arena', 'price': 'Â£21.36', 'availability': 'In stock'}
# {'title': 'Adultery', 'price': 'Â£20.88', 'availability': 'In stock'}
# {'title': "A Mother's Reckoning: Living in the Aftermath of Tragedy", 'price': 'Â£19.53', 'availability': 'In stock'}
# {'title': "A Gentleman's Position (Society of Gentlemen #3)", 'price': 'Â£14.75', 'availability': 'In stock'}
# {'title': '11/22/63', 'price': 'Â£48.48', 'availability': 'In stock'}
# {'title': '10% Happier: How I Tamed the Voice in My Head, Reduced Stress Without Losing My Edge, and Found Self-Help That Actually Works', 'price': 'Â£24.57', 'availability': 'In stock'}
# {'title': '10-Day Green Smoothie Cleanse: Lose Up to 15 Pounds in 10 Days!', 'price': 'Â£49.71', 'availability': 'In stock'}
# {'title': 'Without Shame', 'price': 'Â£48.27', 'availability': 'In stock'}
# {'title': 'Watchmen', 'price': 'Â£58.05', 'availability': 'In stock'}
# {'title': 'Unlimited Intuition Now', 'price': 'Â£58.87', 'availability': 'In stock'}
# {'title': 'Underlying Notes', 'price': 'Â£11.82', 'availability': 'In stock'}
# {'title': 'The Shack', 'price': 'Â£28.03', 'availability': 'In stock'}
# {'title': 'The New Brand You: Your New Image Makes the Sale for You', 'price': 'Â£44.05', 'availability': 'In stock'}
# {'title': 'The Moosewood Cookbook: Recipes from Moosewood Restaurant, Ithaca, New York', 'price': 'Â£12.34', 'availability': 'In stock'}
# {'title': 'The Flowers Lied', 'price': 'Â£16.68', 'availability': 'In stock'}
# {'title': 'The Fabric of the Cosmos: Space, Time, and the Texture of Reality', 'price': 'Â£55.91', 'availability': 'In stock'}
# {'title': 'The Book of Mormon', 'price': 'Â£24.57', 'availability': 'In stock'}
# {'title': 'The Art and Science of Low Carbohydrate Living', 'price': 'Â£52.98', 'availability': 'In stock'}
# {'title': 'The Alien Club', 'price': 'Â£54.40', 'availability': 'In stock'}
# {'title': 'Suzie Snowflake: One beautiful flake (a self-esteem story)', 'price': 'Â£54.81', 'availability': 'In stock'}
# {'title': 'Nap-a-Roo', 'price': 'Â£25.08', 'availability': 'In stock'}
# {'title': 'NaNo What Now? Finding your editing process, revising your NaNoWriMo book and building a writing career through publishing and beyond', 'price': 'Â£10.41', 'availability': 'In stock'}
# {'title': 'Modern Day Fables', 'price': 'Â£47.44', 'availability': 'In stock'}
# {'title': "If I Gave You God's Phone Number....: Searching for Spirituality in America", 'price': 'Â£20.91', 'availability': 'In stock'}
# {'title': 'Fruits Basket, Vol. 9 (Fruits Basket #9)', 'price': 'Â£33.95', 'availability': 'In stock'}
# {'title': 'Dress Your Family in Corduroy and Denim', 'price': 'Â£43.68', 'availability': 'In stock'}
# {'title': "Don't Forget Steven", 'price': 'Â£33.23', 'availability': 'In stock'}
# {'title': "Chernobyl 01:23:40: The Incredible True Story of the World's Worst Nuclear Disaster", 'price': 'Â£35.92', 'availability': 'In stock'}
# {'title': 'Art and Fear: Observations on the Perils (and Rewards) of Artmaking', 'price': 'Â£48.63', 'availability': 'In stock'}
# {'title': 'A Shard of Ice (The Black Symphony Saga #1)', 'price': 'Â£56.63', 'availability': 'In stock'}
# {'title': "A Hero's Curse (The Unseen Chronicles #1)", 'price': 'Â£50.49', 'availability': 'In stock'}
# {'title': '23 Degrees South: A Tropical Tale of Changing Whether...', 'price': 'Â£35.79', 'availability': 'In stock'}
# {'title': 'Zero to One: Notes on Startups, or How to Build the Future', 'price': 'Â£34.06', 'availability': 'In stock'}
# {'title': 'Why Not Me?', 'price': 'Â£17.76', 'availability': 'In stock'}
# {'title': 'When Breath Becomes Air', 'price': 'Â£39.36', 'availability': 'In stock'}
# {'title': 'Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel', 'price': 'Â£36.94', 'availability': 'In stock'}
# {'title': 'The Unlikely Pilgrimage of Harold Fry (Harold Fry #1)', 'price': 'Â£43.62', 'availability': 'In stock'}
# {'title': 'The New Drawing on the Right Side of the Brain', 'price': 'Â£43.02', 'availability': 'In stock'}
# {'title': "The Midnight Assassin: Panic, Scandal, and the Hunt for America's First Serial Killer", 'price': 'Â£28.45', 'availability': 'In stock'}
# {'title': 'The Martian (The Martian #1)', 'price': 'Â£41.39', 'availability': 'In stock'}
# {'title': 'The High Mountains of Portugal', 'price': 'Â£51.15', 'availability': 'In stock'}
# {'title': 'The Grownup', 'price': 'Â£35.88', 'availability': 'In stock'}
# {'title': "The E-Myth Revisited: Why Most Small Businesses Don't Work and What to Do About It", 'price': 'Â£36.91', 'availability': 'In stock'}
# {'title': 'South of Sunshine', 'price': 'Â£28.93', 'availability': 'In stock'}
# {'title': 'Smarter Faster Better: The Secrets of Being Productive in Life and Business', 'price': 'Â£38.89', 'availability': 'In stock'}
# {'title': 'Silence in the Dark (Logan Point #4)', 'price': 'Â£58.33', 'availability': 'In stock'}
# {'title': 'Shadows of the Past (Logan Point #1)', 'price': 'Â£39.67', 'availability': 'In stock'}
# {'title': 'Roller Girl', 'price': 'Â£14.10', 'availability': 'In stock'}
# {'title': 'Rising Strong', 'price': 'Â£21.82', 'availability': 'In stock'}
# ...
# {'title': 'House of Lost Worlds: Dinosaurs, Dynasties, and the Story of Life on Earth', 'price': 'Â£43.70', 'availability': 'In stock'}
# {'title': 'House of Leaves', 'price': 'Â£54.89', 'availability': 'In stock'}
# {'title': 'Horrible Bear!', 'price': 'Â£37.52', 'availability': 'In stock'}
# {'title': 'Holidays on Ice', 'price': 'Â£51.07', 'availability': 'In stock'}
# {'title': 'Heir to the Sky', 'price': 'Â£44.07', 'availability': 'In stock'}
# {'title': 'Green Eggs and Ham (Beginner Books B-16)', 'price': 'Â£10.79', 'availability': 'In stock'}
# {'title': 'Grayson, Vol 3: Nemesis (Grayson #3)', 'price': 'Â£42.72', 'availability': 'In stock'}
# {'title': 'Gratitude', 'price': 'Â£26.66', 'availability': 'In stock'}
# {'title': 'Gone Girl', 'price': 'Â£37.60', 'availability': 'In stock'}
# {'title': 'Golden (Heart of Dread #3)', 'price': 'Â£42.21', 'availability': 'In stock'}
# {'title': 'Girl in the Blue Coat', 'price': 'Â£46.83', 'availability': 'In stock'}
# {'title': 'Fruits Basket, Vol. 3 (Fruits Basket #3)', 'price': 'Â£45.17', 'availability': 'In stock'}
# {'title': 'Friday Night Lights: A Town, a Team, and a Dream', 'price': 'Â£51.22', 'availability': 'In stock'}
# {'title': 'Fire Bound (Sea Haven/Sisters of the Heart #5)', 'price': 'Â£21.28', 'availability': 'In stock'}
# {'title': 'Fifty Shades Freed (Fifty Shades #3)', 'price': 'Â£15.36', 'availability': 'In stock'}
# {'title': 'Fellside', 'price': 'Â£38.62', 'availability': 'In stock'}
# {'title': 'Extreme Prey (Lucas Davenport #26)', 'price': 'Â£25.40', 'availability': 'In stock'}
# {'title': 'Eragon (The Inheritance Cycle #1)', 'price': 'Â£43.87', 'availability': 'In stock'}
# {'title': 'Eclipse (Twilight #3)', 'price': 'Â£18.74', 'availability': 'In stock'}
# {'title': 'Dune (Dune #1)', 'price': 'Â£54.86', 'availability': 'In stock'}
# {'title': 'Dracula', 'price': 'Â£52.62', 'availability': 'In stock'}
# {'title': 'Do Androids Dream of Electric Sheep? (Blade Runner #1)', 'price': 'Â£51.48', 'availability': 'In stock'}
# {'title': 'Disrupted: My Misadventure in the Start-Up Bubble', 'price': 'Â£15.28', 'availability': 'In stock'}
# {'title': 'Dead Wake: The Last Crossing of the Lusitania', 'price': 'Â£39.24', 'availability': 'In stock'}
# {'title': 'David and Goliath: Underdogs, Misfits, and the Art of Battling Giants', 'price': 'Â£17.81', 'availability': 'In stock'}
# {'title': 'Darkfever (Fever #1)', 'price': 'Â£56.02', 'availability': 'In stock'}
# {'title': 'Dark Places', 'price': 'Â£23.90', 'availability': 'In stock'}
# {'title': 'Crazy Rich Asians (Crazy Rich Asians #1)', 'price': 'Â£49.13', 'availability': 'In stock'}
# {'title': 'Counting Thyme', 'price': 'Â£10.62', 'availability': 'In stock'}
# {'title': 'Cosmos', 'price': 'Â£36.17', 'availability': 'In stock'}
# {'title': 'Civilization and Its Discontents', 'price': 'Â£59.95', 'availability': 'In stock'}
# {'title': 'Cinder (The Lunar Chronicles #1)', 'price': 'Â£26.09', 'availability': 'In stock'}
# {'title': "Catastrophic Happiness: Finding Joy in Childhood's Messy Years", 'price': 'Â£37.35', 'availability': 'In stock'}
# {'title': 'Career of Evil (Cormoran Strike #3)', 'price': 'Â£24.72', 'availability': 'In stock'}
# {'title': 'Breaking Dawn (Twilight #4)', 'price': 'Â£35.28', 'availability': 'In stock'}
# {'title': 'Brave Enough', 'price': 'Â£51.32', 'availability': 'In stock'}
# {'title': 'Boy Meets Boy', 'price': 'Â£21.12', 'availability': 'In stock'}
# {'title': 'Born to Run: A Hidden Tribe, Superathletes, and the Greatest Race the World Has Never Seen', 'price': 'Â£27.35', 'availability': 'In stock'}
# {'title': 'Blink: The Power of Thinking Without Thinking', 'price': 'Â£21.74', 'availability': 'In stock'}
# {'title': 'Black Flags: The Rise of ISIS', 'price': 'Â£40.87', 'availability': 'In stock'}
# {'title': 'Black Butler, Vol. 1 (Black Butler #1)', 'price': 'Â£49.31', 'availability': 'In stock'}
# {'title': 'Big Little Lies', 'price': 'Â£22.11', 'availability': 'In stock'}
# {'title': 'Between Shades of Gray', 'price': 'Â£20.79', 'availability': 'In stock'}
# {'title': "Best of My Love (Fool's Gold #20)", 'price': 'Â£27.41', 'availability': 'In stock'}
# {'title': 'Beowulf', 'price': 'Â£38.35', 'availability': 'In stock'}
# {'title': 'Beautiful Creatures (Caster Chronicles #1)', 'price': 'Â£21.55', 'availability': 'In stock'}
# {'title': 'Awkward', 'price': 'Â£38.02', 'availability': 'In stock'}
# {'title': 'Ash', 'price': 'Â£22.06', 'availability': 'In stock'}
# {'title': 'Are We There Yet?', 'price': 'Â£10.66', 'availability': 'In stock'}
# {'title': 'Are We Smart Enough to Know How Smart Animals Are?', 'price': 'Â£56.58', 'availability': 'In stock'}
# {'title': 'Annie on My Mind', 'price': 'Â£36.83', 'availability': 'In stock'}
# {'title': 'And Then There Were None', 'price': 'Â£35.01', 'availability': 'In stock'}
# {'title': 'A Walk in the Woods: Rediscovering America on the Appalachian Trail', 'price': 'Â£30.48', 'availability': 'In stock'}
# {'title': 'A Visit from the Goon Squad', 'price': 'Â£14.08', 'availability': 'In stock'}
# {'title': 'A Storm of Swords (A Song of Ice and Fire #3)', 'price': 'Â£31.22', 'availability': 'In stock'}
# {'title': 'A Heartbreaking Work of Staggering Genius', 'price': 'Â£54.29', 'availability': 'In stock'}
# {'title': '8 Keys to Mental Health Through Exercise', 'price': 'Â£31.04', 'availability': 'In stock'}
# {'title': '#GIRLBOSS', 'price': 'Â£50.96', 'availability': 'In stock'}
# {'title': 'The Suffragettes (Little Black Classics, #96)', 'price': 'Â£11.89', 'availability': 'In stock'}
# {'title': 'The Sense of an Ending', 'price': 'Â£31.38', 'availability': 'In stock'}
# {'title': "The Sandman, Vol. 2: The Doll's House (The Sandman (volumes) #2)", 'price': 'Â£54.81', 'availability': 'In stock'}
# {'title': 'The Course of Love', 'price': 'Â£16.78', 'availability': 'In stock'}
# {'title': 'Sugar Rush (Offensive Line #2)', 'price': 'Â£24.42', 'availability': 'In stock'}
# {'title': 'Saga, Volume 2 (Saga (Collected Editions) #2)', 'price': 'Â£11.75', 'availability': 'In stock'}
# {'title': 'Run, Spot, Run: The Ethics of Keeping Pets', 'price': 'Â£20.02', 'availability': 'In stock'}
# {'title': 'New Moon (Twilight #2)', 'price': 'Â£12.86', 'availability': 'In stock'}
# {'title': 'Life', 'price': 'Â£31.58', 'availability': 'In stock'}
# {'title': "Kindle Paperwhite User's Guide", 'price': 'Â£34.00', 'availability': 'In stock'}
# {'title': 'H is for Hawk', 'price': 'Â£57.42', 'availability': 'In stock'}
# {'title': 'Girl Online On Tour (Girl Online #2)', 'price': 'Â£53.47', 'availability': 'In stock'}
# {'title': 'Fruits Basket, Vol. 2 (Fruits Basket #2)', 'price': 'Â£11.64', 'availability': 'In stock'}
# {'title': 'Diary of a Minecraft Zombie Book 1: A Scare of a Dare (An Unofficial Minecraft Book)', 'price': 'Â£52.88', 'availability': 'In stock'}
# {'title': 'Y: The Last Man, Vol. 1: Unmanned (Y: The Last Man #1)', 'price': 'Â£18.51', 'availability': 'In stock'}
# {'title': 'While You Were Mine', 'price': 'Â£41.32', 'availability': 'In stock'}
# {'title': 'Where Lightning Strikes (Bleeding Stars #3)', 'price': 'Â£39.77', 'availability': 'In stock'}
# {'title': "When I'm Gone", 'price': 'Â£51.96', 'availability': 'In stock'}
# {'title': 'Ways of Seeing', 'price': 'Â£39.51', 'availability': 'In stock'}
# {'title': 'Vampire Knight, Vol. 1 (Vampire Knight #1)', 'price': 'Â£15.40', 'availability': 'In stock'}
# {'title': 'Vampire Girl (Vampire Girl #1)', 'price': 'Â£53.82', 'availability': 'In stock'}
# {'title': 'Twenty Love Poems and a Song of Despair', 'price': 'Â£30.95', 'availability': 'In stock'}
# {'title': 'Travels with Charley: In Search of America', 'price': 'Â£57.82', 'availability': 'In stock'}
# {'title': 'Three Wishes (River of Time: California #1)', 'price': 'Â£44.18', 'availability': 'In stock'}
# {'title': 'This One Moment (Pushing Limits #1)', 'price': 'Â£48.71', 'availability': 'In stock'}
# {'title': 'The Zombie Room', 'price': 'Â£19.69', 'availability': 'In stock'}
# {'title': 'The Wicked + The Divine, Vol. 1: The Faust Act (The Wicked + The Divine)', 'price': 'Â£36.52', 'availability': 'In stock'}
# {'title': 'The Tumor', 'price': 'Â£41.56', 'availability': 'In stock'}
# {'title': 'The Story of Hong Gildong', 'price': 'Â£43.19', 'availability': 'In stock'}
# {'title': 'The Silent Wife', 'price': 'Â£12.34', 'availability': 'In stock'}
# {'title': 'The Silent Twin (Detective Jennifer Knight #3)', 'price': 'Â£36.25', 'availability': 'In stock'}
# {'title': 'The Selfish Gene', 'price': 'Â£29.45', 'availability': 'In stock'}
# {'title': 'The Secret Healer', 'price': 'Â£34.56', 'availability': 'In stock'}
# {'title': 'The Sandman, Vol. 1: Preludes and Nocturnes (The Sandman (volumes) #1)', 'price': 'Â£54.12', 'availability': 'In stock'}
# {'title': 'The Republic', 'price': 'Â£33.78', 'availability': 'In stock'}
# {'title': 'The Odyssey', 'price': 'Â£29.64', 'availability': 'In stock'}
# {'title': "The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency #1)", 'price': 'Â£57.70', 'availability': 'In stock'}
# {'title': 'The Nicomachean Ethics', 'price': 'Â£36.34', 'availability': 'In stock'}
# {'title': 'The Name of the Wind (The Kingkiller Chronicle #1)', 'price': 'Â£50.59', 'availability': 'In stock'}
# {'title': 'The Mirror & the Maze (The Wrath and the Dawn #1.5)', 'price': 'Â£29.38', 'availability': 'In stock'}
# {'title': 'The Little Prince', 'price': 'Â£45.42', 'availability': 'In stock'}
# {'title': 'The Light of the Fireflies', 'price': 'Â£54.43', 'availability': 'In stock'}
# {'title': 'The Last Girl (The Dominion Trilogy #1)', 'price': 'Â£36.26', 'availability': 'In stock'}
# {'title': 'The Iliad', 'price': 'Â£16.16', 'availability': 'In stock'}
# {'title': 'The Hook Up (Game On #1)', 'price': 'Â£36.29', 'availability': 'In stock'}
# {'title': 'The Haters', 'price': 'Â£27.89', 'availability': 'In stock'}
# {'title': 'The Girl You Lost', 'price': 'Â£12.29', 'availability': 'In stock'}
# {'title': 'The Girl In The Ice (DCI Erika Foster #1)', 'price': 'Â£15.85', 'availability': 'In stock'}
# {'title': 'The End of the Jesus Era (An Investigation #1)', 'price': 'Â£14.40', 'availability': 'In stock'}
# {'title': 'The Edge of Reason (Bridget Jones #2)', 'price': 'Â£19.18', 'availability': 'In stock'}
# {'title': 'The Complete Maus (Maus #1-2)', 'price': 'Â£10.64', 'availability': 'In stock'}
# {'title': 'The Communist Manifesto', 'price': 'Â£14.76', 'availability': 'In stock'}
# {'title': 'The Bhagavad Gita', 'price': 'Â£57.49', 'availability': 'In stock'}
# {'title': 'The Bette Davis Club', 'price': 'Â£30.66', 'availability': 'In stock'}
# {'title': 'The Art of Not Breathing', 'price': 'Â£40.83', 'availability': 'In stock'}
# {'title': 'Taking Shots (Assassins #1)', 'price': 'Â£18.88', 'availability': 'In stock'}
# {'title': 'Starlark', 'price': 'Â£25.83', 'availability': 'In stock'}
# {'title': 'Skip Beat!, Vol. 01 (Skip Beat! #1)', 'price': 'Â£42.12', 'availability': 'In stock'}
# {'title': 'Sister Sable (The Mad Queen #1)', 'price': 'Â£13.33', 'availability': 'In stock'}
# {'title': 'Shatter Me (Shatter Me #1)', 'price': 'Â£42.40', 'availability': 'In stock'}
# {'title': 'Shameless', 'price': 'Â£58.35', 'availability': 'In stock'}
# {'title': 'Shadow Rites (Jane Yellowrock #10)', 'price': 'Â£21.72', 'availability': 'In stock'}
# {'title': 'Settling the Score (The Summer Games #1)', 'price': 'Â£44.91', 'availability': 'In stock'}
# {'title': 'Sense and Sensibility', 'price': 'Â£37.46', 'availability': 'In stock'}
# {'title': 'Saga, Volume 1 (Saga (Collected Editions) #1)', 'price': 'Â£28.48', 'availability': 'In stock'}
# {'title': 'Rhythm, Chord & Malykhin', 'price': 'Â£28.34', 'availability': 'In stock'}
# {'title': 'Rat Queens, Vol. 1: Sass & Sorcery (Rat Queens (Collected Editions) #1-5)', 'price': 'Â£46.96', 'availability': 'In stock'}
# {'title': 'Paradise Lost (Paradise #1)', 'price': 'Â£24.96', 'availability': 'In stock'}
# {'title': 'Paper Girls, Vol. 1 (Paper Girls #1-5)', 'price': 'Â£21.71', 'availability': 'In stock'}
# {'title': 'Ouran High School Host Club, Vol. 1 (Ouran High School Host Club #1)', 'price': 'Â£29.87', 'availability': 'In stock'}
# {'title': 'Origins (Alphas 0.5)', 'price': 'Â£28.99', 'availability': 'In stock'}
# {'title': 'One Second (Seven #7)', 'price': 'Â£52.94', 'availability': 'In stock'}
# {'title': 'On the Road (Duluoz Legend)', 'price': 'Â£32.36', 'availability': 'In stock'}
# {'title': "Old Records Never Die: One Man's Quest for His Vinyl and His Past", 'price': 'Â£55.66', 'availability': 'In stock'}
# {'title': 'Off Sides (Off #1)', 'price': 'Â£39.45', 'availability': 'In stock'}
# {'title': 'Of Mice and Men', 'price': 'Â£47.11', 'availability': 'In stock'}
# {'title': 'Myriad (Prentor #1)', 'price': 'Â£58.75', 'availability': 'In stock'}
# {'title': 'My Perfect Mistake (Over the Top #1)', 'price': 'Â£38.92', 'availability': 'In stock'}
# {'title': 'Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1)', 'price': 'Â£39.39', 'availability': 'In stock'}
# {'title': 'Meditations', 'price': 'Â£25.89', 'availability': 'In stock'}
# {'title': 'Matilda', 'price': 'Â£28.34', 'availability': 'In stock'}
# {'title': 'Lost Among the Living', 'price': 'Â£27.70', 'availability': 'In stock'}
# {'title': 'Lord of the Flies', 'price': 'Â£24.89', 'availability': 'In stock'}
# {'title': 'Listen to Me (Fusion #1)', 'price': 'Â£58.99', 'availability': 'In stock'}
# {'title': 'Kitchens of the Great Midwest', 'price': 'Â£57.20', 'availability': 'In stock'}
# {'title': 'Jane Eyre', 'price': 'Â£38.43', 'availability': 'In stock'}
# {'title': 'Imperfect Harmony', 'price': 'Â£34.74', 'availability': 'In stock'}
# {'title': 'Icing (Aces Hockey #2)', 'price': 'Â£40.44', 'availability': 'In stock'}
# {'title': 'Hawkeye, Vol. 1: My Life as a Weapon (Hawkeye #1)', 'price': 'Â£45.24', 'availability': 'In stock'}
# {'title': "Having the Barbarian's Baby (Ice Planet Barbarians #7.5)", 'price': 'Â£34.96', 'availability': 'In stock'}
# {'title': 'Giant Days, Vol. 1 (Giant Days #1-4)', 'price': 'Â£56.76', 'availability': 'In stock'}
# {'title': 'Fruits Basket, Vol. 1 (Fruits Basket #1)', 'price': 'Â£40.28', 'availability': 'In stock'}
# {'title': 'Frankenstein', 'price': 'Â£38.00', 'availability': 'In stock'}
# {'title': 'Forever Rockers (The Rocker #12)', 'price': 'Â£28.80', 'availability': 'In stock'}
# {'title': 'Fighting Fate (Fighting #6)', 'price': 'Â£39.24', 'availability': 'In stock'}
# {'title': 'Emma', 'price': 'Â£32.93', 'availability': 'In stock'}
# {'title': 'Eat, Pray, Love', 'price': 'Â£51.32', 'availability': 'In stock'}
# {'title': 'Deep Under (Walker Security #1)', 'price': 'Â£47.09', 'availability': 'In stock'}
# {'title': "Choosing Our Religion: The Spiritual Lives of America's Nones", 'price': 'Â£28.42', 'availability': 'In stock'}
# {'title': 'Charlie and the Chocolate Factory (Charlie Bucket #1)', 'price': 'Â£22.85', 'availability': 'In stock'}
# {'title': "Charity's Cross (Charles Towne Belles #4)", 'price': 'Â£41.24', 'availability': 'In stock'}
# {'title': 'Bright Lines', 'price': 'Â£39.07', 'availability': 'In stock'}
# {'title': "Bridget Jones's Diary (Bridget Jones #1)", 'price': 'Â£29.82', 'availability': 'In stock'}
# {'title': 'Bounty (Colorado Mountain #7)', 'price': 'Â£37.26', 'availability': 'In stock'}
# {'title': 'Blood Defense (Samantha Brinkman #1)', 'price': 'Â£20.30', 'availability': 'In stock'}
# {'title': 'Bleach, Vol. 1: Strawberry and the Soul Reapers (Bleach #1)', 'price': 'Â£34.65', 'availability': 'In stock'}
# {'title': 'Beyond Good and Evil', 'price': 'Â£43.38', 'availability': 'In stock'}
# {'title': "Alice in Wonderland (Alice's Adventures in Wonderland #1)", 'price': 'Â£55.53', 'availability': 'In stock'}
# {'title': 'Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)', 'price': 'Â£57.06', 'availability': 'In stock'}
# {'title': "A Spy's Devotion (The Regency Spies of London #1)", 'price': 'Â£16.97', 'availability': 'In stock'}
# {'title': "1st to Die (Women's Murder Club #1)", 'price': 'Â£53.98', 'availability': 'In stock'}
# {'title': '1,000 Places to See Before You Die', 'price': 'Â£26.08', 'availability': 'In stock'}

# %%
#Iterate over scrape_all() using a for loop and print the first 5 items to verify that your generator pipeline works.
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# Generator to fetch pages lazily
def fetch_page(url):

    while url:
        response = requests.get(url)
        html = response.text
        yield html

        # Find next page
        soup = BeautifulSoup(html, "html.parser")
        next_button = soup.find("li", class_="next")
        if next_button and next_button.a:
            next_href = next_button.a.get("href")
            url = urljoin(start_url, next_href)
        else:
            url = None

# Generator to parse items from a single page
def parse_items(html):
    soup = BeautifulSoup(html, "html.parser")
    books = soup.find_all("article", class_="product_pod")
    for book in books:
        title = book.h3.a["title"]
        price = book.find("p", class_="price_color").text
        availability = book.find("p", class_="instock availability").text.strip()
        yield {
            "title": title,
            "price": price,
            "availability": availability
        }

# Generator to scrape all items across all pages lazily
def scrape_all(start_url):
    for page_html in fetch_page(start_url):          # fetch one page at a time
        for item in parse_items(page_html):         # parse items lazily from that page
            yield item                              # yield one item at a time

# Usage example
start_url = "http://books.toscrape.com/catalogue/page-1.html"
for i, book in enumerate(scrape_all(start_url), start=1):
    print(book)          # print the book dictionary
    if i >= 5:           # stop after 5 books
        break
# Out:
# {'title': 'A Light in the Attic', 'price': 'Â£51.77', 'availability': 'In stock'}
# {'title': 'Tipping the Velvet', 'price': 'Â£53.74', 'availability': 'In stock'}
# {'title': 'Soumission', 'price': 'Â£50.10', 'availability': 'In stock'}
# {'title': 'Sharp Objects', 'price': 'Â£47.82', 'availability': 'In stock'}
# {'title': 'Sapiens: A Brief History of Humankind', 'price': 'Â£54.23', 'availability': 'In stock'}

# %%
#Add a page counter inside fetch_page() to track how many pages were visited and print the total pages at the end.
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

def fetch_page(start_url):
    url = start_url
    page_number = 0
    while url:
        page_number += 1
        html = requests.get(url).text
        yield html  # yield one page HTML

        # Find next page
        soup = BeautifulSoup(html, "html.parser")
        next_button = soup.find("li", class_="next")
        if next_button and next_button.a:
            url = urljoin(start_url, next_button.a["href"])
        else:
            url = None

    print(f"Total pages visited: {page_number}")

# Usage: iterate over pages
start_url = "http://books.toscrape.com/catalogue/page-1.html"
for page in fetch_page(start_url):
    print("Got a page!")
# Out:
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Got a page!
# Total pages visited: 50

# %%
#Validate generator behavior by confirming the script processes items only when needed (no preloading, no storing all data at once).
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# Generator: fetch pages lazily
def fetch_page(start_url):
    url = start_url
    page_number = 0
    while url:
        page_number += 1
        print(f"[fetch_page] Fetching page {page_number}: {url}")
        html = requests.get(url).text
        yield html  # yield page HTML only when needed

        # Find next page
        soup = BeautifulSoup(html, "html.parser")
        next_button = soup.find("li", class_="next")
        if next_button and next_button.a:
            url = urljoin(start_url, next_button.a["href"])
        else:
            url = None
    print(f"[fetch_page] Total pages visited: {page_number}")

# Generator: parse items lazily from a page
def parse_items(html):
    soup = BeautifulSoup(html, "html.parser")
    books = soup.find_all("article", class_="product_pod")
    for book in books:
        print(f"[parse_items] Processing book: {book.h3.a['title']}")
        yield {
            "title": book.h3.a["title"],
            "price": book.find("p", class_="price_color").text,
            "availability": book.find("p", class_="instock availability").text.strip()
        }

# Generator: combine fetch and parse
def scrape_all(start_url):
    for page_html in fetch_page(start_url):
        for item in parse_items(page_html):
            yield item  # yield one item at a time

# Usage: process only first 5 books
start_url = "http://books.toscrape.com/catalogue/page-1.html"

for i, book in enumerate(scrape_all(start_url), start=1):
    print(f"[main] Got book {i}: {book['title']}")
    if i >= 5:
        break
# Out:
# [fetch_page] Fetching page 1: http://books.toscrape.com/catalogue/page-1.html
# [parse_items] Processing book: A Light in the Attic
# [main] Got book 1: A Light in the Attic
# [parse_items] Processing book: Tipping the Velvet
# [main] Got book 2: Tipping the Velvet
# [parse_items] Processing book: Soumission
# [main] Got book 3: Soumission
# [parse_items] Processing book: Sharp Objects
# [main] Got book 4: Sharp Objects
# [parse_items] Processing book: Sapiens: A Brief History of Humankind
# [main] Got book 5: Sapiens: A Brief History of Humankind
